# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

DATA_DIR='/kaggle/input/8-facial-expressions-for-yolo/9 Facial Expressions you need'
train = os.listdir(os.path.join(DATA_DIR,'train'))
test = os.listdir(os.path.join(DATA_DIR,'test'))
val=os.listdir(os.path.join(DATA_DIR,'valid'))
print(f'Train - {train}')
print(f'Test - {test}')
print(f'Val - {val}')
# Out:
# Train - ['labels', 'images']
# Test - ['labels', 'images']
# Val - ['labels', 'images']

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical

IMG_SIZE = 48
EMOTIONS = ['Happy', 'Sad', 'Angry', 'Surprised', 'Neutral', 'Disgusted', 'Fear', 'Sleepy', 'Contempt']  # update based on your labels
emotion_to_idx = {e: i for i, e in enumerate(EMOTIONS)}
idx_to_emotion = {i: e for i, e in enumerate(EMOTIONS)} # Add mapping from index to emotion

def load_data(folder_path):
    image_dir = os.path.join(folder_path, 'images')
    label_dir = os.path.join(folder_path, 'labels')

    images = []
    labels = []

    # Get list of label files
    label_files = sorted([f for f in os.listdir(label_dir) if f.endswith('.txt')])

    for label_fname in label_files:
        image_fname = label_fname.replace('.txt', '.jpg')
        image_path = os.path.join(image_dir, image_fname)
        label_path = os.path.join(label_dir, label_fname)

        # Check if the corresponding image file exists
        if not os.path.exists(image_path):
            print(f"Warning: Image file not found for label file {label_path}. Skipping.")
            continue

        # Load image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Warning: Could not read image file {image_path}. Skipping.")
            continue
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))  # Resize to 48×48
        images.append(img)

        # Load and parse label from YOLO format
        with open(label_path, 'r') as f:
            label_content = f.read().strip()
            # Assuming the first number in the line is the class ID
            try:
                class_id = int(label_content.split()[0])
                labels.append(class_id)
            except (ValueError, IndexError):
                print(f"Warning: Could not parse label from file {label_path}. Content: '{label_content}'. Skipping.")
                images.pop() # Remove the image if label parsing fails
                continue


    images = np.array(images)
    labels = np.array(labels)
    return images, labels
     

# Load full data from train folder
images, labels = load_data(os.path.join(DATA_DIR, 'test'))

# Normalize pixel values to be between 0 and 1
images = images / 255.0

# Reduce dataset size
n_train = 5000
n_test = 3000

train_images = images[:n_train]
train_labels = labels[:n_train]
test_images = images[-n_test:]
test_labels = labels[-n_test:]

# Add grayscale channel dimension: (N, 48, 48, 1)
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# One-hot encode the labels
train_labels_categorical = to_categorical(train_labels, num_classes=len(EMOTIONS))
test_labels_categorical = to_categorical(test_labels, num_classes=len(EMOTIONS))

# Final checks
print(f"Train images shape: {train_images.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Train labels shape: {train_labels_categorical.shape}")
print(f"Test labels shape: {test_labels_categorical.shape}")
# Out:
# 2025-08-09 03:42:45.485770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754710965.726717      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754710965.794010      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Train images shape: (1700, 48, 48, 1)
# Test images shape: (1700, 48, 48, 1)
# Train labels shape: (1700, 9)
# Test labels shape: (1700, 9)

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.42.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.42 (from pennylane)
#   Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (25.0)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.42->pennylane)
#   Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2.4.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.6.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pennylane) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pennylane) (2024.2.0)
# Downloading pennylane-0.42.1-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 58.1 MB/s eta 0:00:00:00:010:01
# Downloading autoray-0.7.2-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 36.0 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 68.1 MB/s eta 0:00:00:00:01
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 55.2 MB/s eta 0:00:00:00:01
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 8.8 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 92.9 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: appdirs, scipy-openblas32, autoray, diastatic-malt, rustworkx, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.2 diastatic-malt-2.15.2 pennylane-0.42.1 pennylane-lightning-0.42.0 rustworkx-0.16.0 scipy-openblas32-0.3.30.0.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Fix random seeds
np.random.seed(0)
tf.random.set_seed(0)

# Number of classes (for this dataset)
num_classes = len(EMOTIONS)

# Define qubit patch sizes
qubit_patch_shapes = {
    4: (2, 2),
    6: (3, 2),
    8: (4, 2),
    10: (5, 2),
    12: (4, 3),
}

# ------------------ Quantum Circuit Creation -------------------
def create_circuit(n_qubits, n_layers=1):
    dev = qml.device("default.qubit", wires=n_qubits)
    rand_params = np.random.uniform(high=2*np.pi, size=(n_layers, n_qubits))

    @qml.qnode(dev)
    def circuit(phi):
        # Encode classical data into qubits
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)
        RandomLayers(rand_params, wires=range(n_qubits))
        return [qml.expval(qml.PauliZ(j)) for j in range(n_qubits)]

    return circuit

# ------------------ Quantum Convolution -------------------
def quanv(image, circuit, patch_h, patch_w):
    out_h = (image.shape[0] - patch_h) // 2 + 1
    out_w = (image.shape[1] - patch_w) // 2 + 1
    n_qubits = patch_h * patch_w
    out = np.zeros((out_h, out_w, n_qubits))
    for j in range(0, image.shape[0] - patch_h + 1, 2):
        for k in range(0, image.shape[1] - patch_w + 1, 2):
            patch = image[j:j+patch_h, k:k+patch_w, 0].flatten()
            q_results = circuit(patch)
            out[j//2, k//2, :] = q_results
    return out

# ------------------ Classical Model -------------------
def build_model(input_shape, num_classes):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ------------------ Run for Multiple Qubits -------------------
results = {}
n_qubits=12 # Changed from list [6] to integer 6

print(f"\n=== Running for {n_qubits} Qubits ===")
patch_h, patch_w = qubit_patch_shapes[n_qubits]
circuit = create_circuit(n_qubits)

# Show quantum circuit diagram
print(f"\nQuantum Circuit for {n_qubits} Qubits:")
fig, ax = qml.draw_mpl(circuit)(np.random.rand(n_qubits))
plt.show()

# Quantum preprocessing
print("Quantum preprocessing (train)...")
q_train_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in train_images])
print("Quantum preprocessing (test)...")
q_test_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in test_images])
# Out:
# === Running for 12 Qubits ===
#
# Quantum Circuit for 12 Qubits:
# Quantum preprocessing (train)...
# Quantum preprocessing (test)...

# %%
# Train classical model
model = build_model(q_train_images.shape[1:], num_classes)
model.fit(q_train_images, train_labels, validation_data=(q_test_images, test_labels),
              epochs=800, batch_size=8, verbose=2)

# Predictions & evaluation
y_pred = np.argmax(model.predict(q_test_images), axis=1)

print(f"\nClassification Report ({n_qubits} Qubits):")
print(classification_report(test_labels, y_pred, target_names=EMOTIONS, labels=range(num_classes)))

    # Confusion Matrix
cm = confusion_matrix(test_labels, y_pred, labels=range(num_classes)) # Add labels parameter here as well
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=EMOTIONS, yticklabels=EMOTIONS)
plt.title(f"Confusion Matrix - {n_qubits} Qubits")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Accuracy
acc = model.evaluate(q_test_images, test_labels, verbose=0)[1]
print(f"Test Accuracy ({n_qubits} Qubits): {acc:.4f}")
results[n_qubits] = acc

# ------------------ Accuracy Comparison Plot -------------------
plt.figure(figsize=(8, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Quantum CNN Accuracy vs Number of Qubits (9-class Dataset)")
plt.xlabel("Number of Qubits")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

print("\n=== Final Accuracy Comparison ===")
for q, a in results.items():
    print(f"{q} Qubits: Accuracy = {a:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/800
# 213/213 - 4s - 17ms/step - accuracy: 0.2324 - loss: 2.4772 - val_accuracy: 0.3053 - val_loss: 1.9266
# Epoch 2/800
# 213/213 - 2s - 9ms/step - accuracy: 0.2476 - loss: 1.9554 - val_accuracy: 0.3318 - val_loss: 1.8036
# Epoch 3/800
# 213/213 - 2s - 9ms/step - accuracy: 0.2847 - loss: 1.8953 - val_accuracy: 0.3694 - val_loss: 1.7887
# Epoch 4/800
# 213/213 - 2s - 9ms/step - accuracy: 0.3112 - loss: 1.8146 - val_accuracy: 0.4082 - val_loss: 1.6900
# Epoch 5/800
# 213/213 - 2s - 9ms/step - accuracy: 0.3294 - loss: 1.7560 - val_accuracy: 0.4100 - val_loss: 1.6326
# Epoch 6/800
# 213/213 - 2s - 9ms/step - accuracy: 0.3559 - loss: 1.7144 - val_accuracy: 0.4471 - val_loss: 1.5612
# Epoch 7/800
# 213/213 - 2s - 9ms/step - accuracy: 0.3853 - loss: 1.6385 - val_accuracy: 0.4888 - val_loss: 1.5093
# Epoch 8/800
# 213/213 - 2s - 9ms/step - accuracy: 0.3994 - loss: 1.5795 - val_accuracy: 0.4724 - val_loss: 1.4388
# Epoch 9/800
# 213/213 - 2s - 9ms/step - accuracy: 0.3982 - loss: 1.5508 - val_accuracy: 0.4835 - val_loss: 1.3703
# Epoch 10/800
# 213/213 - 2s - 9ms/step - accuracy: 0.4212 - loss: 1.4996 - val_accuracy: 0.5182 - val_loss: 1.3152
# Epoch 11/800
# 213/213 - 2s - 9ms/step - accuracy: 0.4359 - loss: 1.4674 - val_accuracy: 0.5106 - val_loss: 1.3248
# Epoch 12/800
# 213/213 - 2s - 9ms/step - accuracy: 0.4306 - loss: 1.4330 - val_accuracy: 0.5441 - val_loss: 1.2353
# Epoch 13/800
# 213/213 - 2s - 9ms/step - accuracy: 0.4524 - loss: 1.3802 - val_accuracy: 0.5529 - val_loss: 1.2033
# Epoch 14/800
# 213/213 - 2s - 9ms/step - accuracy: 0.4829 - loss: 1.3318 - val_accuracy: 0.5606 - val_loss: 1.1824
# Epoch 15/800
# 213/213 - 2s - 9ms/step - accuracy: 0.4847 - loss: 1.2880 - val_accuracy: 0.6024 - val_loss: 1.0808
# Epoch 16/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5129 - loss: 1.2564 - val_accuracy: 0.6029 - val_loss: 1.0425
# Epoch 17/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5229 - loss: 1.2356 - val_accuracy: 0.6206 - val_loss: 1.0044
# Epoch 18/800
# 213/213 - 2s - 10ms/step - accuracy: 0.5359 - loss: 1.1825 - val_accuracy: 0.6247 - val_loss: 1.0352
# Epoch 19/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5194 - loss: 1.1815 - val_accuracy: 0.6329 - val_loss: 0.9800
# Epoch 20/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5259 - loss: 1.1840 - val_accuracy: 0.6359 - val_loss: 0.9524
# Epoch 21/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5506 - loss: 1.1157 - val_accuracy: 0.6406 - val_loss: 0.9385
# Epoch 22/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5500 - loss: 1.1087 - val_accuracy: 0.6912 - val_loss: 0.8692
# Epoch 23/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5765 - loss: 1.0622 - val_accuracy: 0.6771 - val_loss: 0.8598
# Epoch 24/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5559 - loss: 1.0791 - val_accuracy: 0.6906 - val_loss: 0.8474
# Epoch 25/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5806 - loss: 1.0621 - val_accuracy: 0.7035 - val_loss: 0.8548
# Epoch 26/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5824 - loss: 1.0151 - val_accuracy: 0.7024 - val_loss: 0.8655
# Epoch 27/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6059 - loss: 0.9959 - val_accuracy: 0.7118 - val_loss: 0.8004
# Epoch 28/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5735 - loss: 1.0515 - val_accuracy: 0.7212 - val_loss: 0.7809
# Epoch 29/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5882 - loss: 1.0118 - val_accuracy: 0.7359 - val_loss: 0.7395
# Epoch 30/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6129 - loss: 0.9781 - val_accuracy: 0.7359 - val_loss: 0.7717
# Epoch 31/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6076 - loss: 0.9675 - val_accuracy: 0.7524 - val_loss: 0.7161
# Epoch 32/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6088 - loss: 0.9477 - val_accuracy: 0.7418 - val_loss: 0.7343
# Epoch 33/800
# 213/213 - 2s - 9ms/step - accuracy: 0.5847 - loss: 0.9952 - val_accuracy: 0.7276 - val_loss: 0.7991
# Epoch 34/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6024 - loss: 0.9534 - val_accuracy: 0.7482 - val_loss: 0.7298
# Epoch 35/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6065 - loss: 0.9266 - val_accuracy: 0.7565 - val_loss: 0.6937
# Epoch 36/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6435 - loss: 0.8896 - val_accuracy: 0.7641 - val_loss: 0.6796
# Epoch 37/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6441 - loss: 0.8764 - val_accuracy: 0.7682 - val_loss: 0.6701
# Epoch 38/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6382 - loss: 0.8972 - val_accuracy: 0.7829 - val_loss: 0.6274
# Epoch 39/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6541 - loss: 0.8692 - val_accuracy: 0.7647 - val_loss: 0.6473
# Epoch 40/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6382 - loss: 0.8628 - val_accuracy: 0.7541 - val_loss: 0.6959
# Epoch 41/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6635 - loss: 0.8387 - val_accuracy: 0.7771 - val_loss: 0.6138
# Epoch 42/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6529 - loss: 0.8473 - val_accuracy: 0.7965 - val_loss: 0.5703
# Epoch 43/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6582 - loss: 0.8346 - val_accuracy: 0.7882 - val_loss: 0.6071
# Epoch 44/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6582 - loss: 0.8531 - val_accuracy: 0.7971 - val_loss: 0.6060
# Epoch 45/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6476 - loss: 0.8448 - val_accuracy: 0.7994 - val_loss: 0.5616
# Epoch 46/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6653 - loss: 0.8223 - val_accuracy: 0.8229 - val_loss: 0.5150
# Epoch 47/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6535 - loss: 0.8573 - val_accuracy: 0.8135 - val_loss: 0.5222
# Epoch 48/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6624 - loss: 0.8405 - val_accuracy: 0.8059 - val_loss: 0.5381
# Epoch 49/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6418 - loss: 0.8637 - val_accuracy: 0.8065 - val_loss: 0.5361
# Epoch 50/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6665 - loss: 0.7918 - val_accuracy: 0.8076 - val_loss: 0.5333
# Epoch 51/800
# 213/213 - 2s - 10ms/step - accuracy: 0.6841 - loss: 0.7866 - val_accuracy: 0.8012 - val_loss: 0.5400
# Epoch 52/800
# 213/213 - 2s - 10ms/step - accuracy: 0.6959 - loss: 0.7536 - val_accuracy: 0.8359 - val_loss: 0.4829
# Epoch 53/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6659 - loss: 0.7942 - val_accuracy: 0.8100 - val_loss: 0.5126
# Epoch 54/800
# 213/213 - 2s - 10ms/step - accuracy: 0.6729 - loss: 0.7776 - val_accuracy: 0.8341 - val_loss: 0.4716
# Epoch 55/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6700 - loss: 0.7854 - val_accuracy: 0.8206 - val_loss: 0.4952
# Epoch 56/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6706 - loss: 0.7805 - val_accuracy: 0.8376 - val_loss: 0.4501
# Epoch 57/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6747 - loss: 0.7984 - val_accuracy: 0.7976 - val_loss: 0.5618
# Epoch 58/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6706 - loss: 0.8126 - val_accuracy: 0.8241 - val_loss: 0.4935
# Epoch 59/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6835 - loss: 0.7978 - val_accuracy: 0.8353 - val_loss: 0.4770
# Epoch 60/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7000 - loss: 0.7305 - val_accuracy: 0.8359 - val_loss: 0.4782
# Epoch 61/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6959 - loss: 0.7386 - val_accuracy: 0.8376 - val_loss: 0.4417
# Epoch 62/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7094 - loss: 0.7170 - val_accuracy: 0.8465 - val_loss: 0.4267
# Epoch 63/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7053 - loss: 0.7232 - val_accuracy: 0.8365 - val_loss: 0.4392
# Epoch 64/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6941 - loss: 0.7447 - val_accuracy: 0.8324 - val_loss: 0.4611
# Epoch 65/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6882 - loss: 0.7389 - val_accuracy: 0.8465 - val_loss: 0.4297
# Epoch 66/800
# 213/213 - 2s - 10ms/step - accuracy: 0.6841 - loss: 0.7382 - val_accuracy: 0.8371 - val_loss: 0.4576
# Epoch 67/800
# 213/213 - 2s - 10ms/step - accuracy: 0.6906 - loss: 0.7526 - val_accuracy: 0.8335 - val_loss: 0.4469
# Epoch 68/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7065 - loss: 0.7115 - val_accuracy: 0.8353 - val_loss: 0.4317
# Epoch 69/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7029 - loss: 0.7083 - val_accuracy: 0.8471 - val_loss: 0.4233
# Epoch 70/800
# 213/213 - 2s - 10ms/step - accuracy: 0.6935 - loss: 0.7387 - val_accuracy: 0.8535 - val_loss: 0.4157
# Epoch 71/800
# 213/213 - 2s - 9ms/step - accuracy: 0.6812 - loss: 0.7655 - val_accuracy: 0.8418 - val_loss: 0.4896
# Epoch 72/800
# 213/213 - 2s - 9ms/step - accuracy: 0.
800
# 213/213 - 2s - 9ms/step - accuracy: 0.7624 - loss: 0.5957 - val_accuracy: 0.8976 - val_loss: 0.2695
# Epoch 198/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7759 - loss: 0.5572 - val_accuracy: 0.8900 - val_loss: 0.2779
# Epoch 199/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7794 - loss: 0.5280 - val_accuracy: 0.9000 - val_loss: 0.2704
# Epoch 200/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7629 - loss: 0.5622 - val_accuracy: 0.9071 - val_loss: 0.2533
# Epoch 201/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7588 - loss: 0.5564 - val_accuracy: 0.9012 - val_loss: 0.2612
# Epoch 202/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7735 - loss: 0.5276 - val_accuracy: 0.9247 - val_loss: 0.2169
# Epoch 203/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7894 - loss: 0.5066 - val_accuracy: 0.9047 - val_loss: 0.2476
# Epoch 204/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7894 - loss: 0.5088 - val_accuracy: 0.9141 - val_loss: 0.2278
# Epoch 205/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7853 - loss: 0.5290 - val_accuracy: 0.9018 - val_loss: 0.2674
# Epoch 206/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7906 - loss: 0.5069 - val_accuracy: 0.9276 - val_loss: 0.2034
# Epoch 207/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7906 - loss: 0.5015 - val_accuracy: 0.9176 - val_loss: 0.2294
# Epoch 208/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7771 - loss: 0.5523 - val_accuracy: 0.9006 - val_loss: 0.2872
# Epoch 209/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7694 - loss: 0.5488 - val_accuracy: 0.9059 - val_loss: 0.2966
# Epoch 210/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7718 - loss: 0.5487 - val_accuracy: 0.9082 - val_loss: 0.2545
# Epoch 211/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7941 - loss: 0.5180 - val_accuracy: 0.9135 - val_loss: 0.2257
# Epoch 212/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8006 - loss: 0.4933 - val_accuracy: 0.9235 - val_loss: 0.2228
# Epoch 213/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7765 - loss: 0.5303 - val_accuracy: 0.9312 - val_loss: 0.2243
# Epoch 214/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7971 - loss: 0.5205 - val_accuracy: 0.9165 - val_loss: 0.2489
# Epoch 215/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7982 - loss: 0.5080 - val_accuracy: 0.9147 - val_loss: 0.2586
# Epoch 216/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7982 - loss: 0.5033 - val_accuracy: 0.9271 - val_loss: 0.2195
# Epoch 217/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7835 - loss: 0.5160 - val_accuracy: 0.9194 - val_loss: 0.2507
# Epoch 218/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7782 - loss: 0.5162 - val_accuracy: 0.9182 - val_loss: 0.2309
# Epoch 219/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7976 - loss: 0.5142 - val_accuracy: 0.9241 - val_loss: 0.2111
# Epoch 220/800
# 213/213 - 2s - 10ms/step - accuracy: 0.7759 - loss: 0.5291 - val_accuracy: 0.9141 - val_loss: 0.2312
# Epoch 221/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7806 - loss: 0.5267 - val_accuracy: 0.9106 - val_loss: 0.2451
# Epoch 222/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7865 - loss: 0.5375 - val_accuracy: 0.9171 - val_loss: 0.2458
# Epoch 223/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7935 - loss: 0.5018 - val_accuracy: 0.9341 - val_loss: 0.1935
# Epoch 224/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7906 - loss: 0.5228 - val_accuracy: 0.9106 - val_loss: 0.2494
# Epoch 225/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7806 - loss: 0.5085 - val_accuracy: 0.9112 - val_loss: 0.2384
# Epoch 226/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7918 - loss: 0.4948 - val_accuracy: 0.9094 - val_loss: 0.2348
# Epoch 227/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7700 - loss: 0.5360 - val_accuracy: 0.9206 - val_loss: 0.2465
# Epoch 228/800
# 213/213 - 2s - 9ms/step - accuracy: 0.7959 - loss: 0.5053 - val_accuracy: 0.9318 - val_loss: 0.2155
# Epoch 229/800
# 213/213 - 2s - 9ms/step - accuracy: 0.
800
# 213/213 - 2s - 9ms/step - accuracy: 0.8335 - loss: 0.4265 - val_accuracy: 0.9312 - val_loss: 0.2712
# Epoch 792/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8353 - loss: 0.3971 - val_accuracy: 0.9529 - val_loss: 0.1397
# Epoch 793/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8318 - loss: 0.4066 - val_accuracy: 0.9541 - val_loss: 0.1311
# Epoch 794/800
# 213/213 - 2s - 10ms/step - accuracy: 0.8206 - loss: 0.4167 - val_accuracy: 0.9500 - val_loss: 0.1421
# Epoch 795/800
# 213/213 - 2s - 10ms/step - accuracy: 0.8400 - loss: 0.3953 - val_accuracy: 0.9476 - val_loss: 0.1469
# Epoch 796/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8329 - loss: 0.4138 - val_accuracy: 0.9453 - val_loss: 0.1577
# Epoch 797/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8312 - loss: 0.4190 - val_accuracy: 0.9518 - val_loss: 0.1409
# Epoch 798/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8271 - loss: 0.4311 - val_accuracy: 0.9465 - val_loss: 0.1555
# Epoch 799/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8312 - loss: 0.4291 - val_accuracy: 0.9565 - val_loss: 0.1321
# Epoch 800/800
# 213/213 - 2s - 9ms/step - accuracy: 0.8388 - loss: 0.3837 - val_accuracy: 0.9488 - val_loss: 0.1479
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report (12 Qubits):
#               precision    recall  f1-score   support
#
#        Happy       0.95      0.95      0.95       297
#          Sad       0.96      0.96      0.96        68
#        Angry       0.65      0.96      0.78        98
#    Surprised       0.98      0.96      0.97       144
#      Neutral       1.00      0.97      0.99       407
#    Disgusted       0.93      0.95      0.94       136
#         Fear       1.00      0.94      0.97       298
#       Sleepy       1.00      0.88      0.94        33
#     Contempt       0.98      0.92      0.95       219
#
#     accuracy                           0.95      1700
#    macro avg       0.94      0.94      0.94      1700
# weighted avg       0.96      0.95      0.95      1700
# Test Accuracy (12 Qubits): 0.9488
# === Final Accuracy Comparison ===
# 12 Qubits: Accuracy = 0.9488

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt
import os

# Make an output folder for PDFs
os.makedirs("quantum_circuits_pdf", exist_ok=True)

# Function to create and save detailed quantum circuits
def save_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    # Random parameters for encoding & random layers
    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)  # Sample classical input for encoding

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding using RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Apply random entangling layers
        RandomLayers(rand_params, wires=range(n_qubits))

        # Measurement
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw circuit
    fig, ax = qml.draw_mpl(circuit, style='pennylane')(sample_inputs)
    plt.title(f"Quantum Circuit with {n_qubits} Qubits & {n_layers} Random Layers")
    
    # Save as PDF
    pdf_path = f"quantum_circuits_pdf/circuit_{n_qubits}qubits.pdf"
    plt.savefig(pdf_path, format='pdf', bbox_inches='tight')
    plt.close()
    print(f"✅ Saved: {pdf_path}")

# Save circuits for 4, 6, 8, 10, 12 qubits
for q in [4, 6, 8, 10, 12]:
    save_detailed_circuit(n_qubits=q, n_layers=2)
# Out:
# ✅ Saved: quantum_circuits_pdf/circuit_4qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_6qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_8qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_10qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_12qubits.pdf

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt
import os
import zipfile

# Make an output folder for PDFs
output_dir = "quantum_circuits_pdf"
os.makedirs(output_dir, exist_ok=True)

# Function to create and save detailed quantum circuits
def save_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    # Random parameters for encoding & random layers
    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)  # Sample classical input for encoding

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding using RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Apply random entangling layers
        RandomLayers(rand_params, wires=range(n_qubits))

        # Measurement
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw circuit
    fig, ax = qml.draw_mpl(circuit, style='pennylane')(sample_inputs)
    plt.title(f"Quantum Circuit with {n_qubits} Qubits & {n_layers} Random Layers")
    
    # Save as PDF
    pdf_path = os.path.join(output_dir, f"circuit_{n_qubits}qubits.pdf")
    plt.savefig(pdf_path, format='pdf', bbox_inches='tight')
    plt.close()
    print(f"✅ Saved: {pdf_path}")

# Save circuits for 4, 6, 8, 10, 12 qubits
for q in [4, 6, 8, 10, 12]:
    save_detailed_circuit(n_qubits=q, n_layers=2)

# Create a ZIP file for download
zip_filename = "quantum_circuits_pdf.zip"
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in os.listdir(output_dir):
        zipf.write(os.path.join(output_dir, file), file)

print(f"📦 All circuits zipped into: {zip_filename}")
# Out:
# ✅ Saved: quantum_circuits_pdf/circuit_4qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_6qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_8qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_10qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_12qubits.pdf
# 📦 All circuits zipped into: quantum_circuits_pdf.zip

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt
import os
import zipfile
from IPython.display import FileLink

# Output folder
output_dir = "quantum_circuits_pdf"
os.makedirs(output_dir, exist_ok=True)

# Function to create and save quantum circuits
def save_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)

    @qml.qnode(dev)
    def circuit(phi):
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)
        RandomLayers(rand_params, wires=range(n_qubits))
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    fig, ax = qml.draw_mpl(circuit, style='pennylane')(sample_inputs)

    pdf_path = os.path.join(output_dir, f"circuit_{n_qubits}qubits.pdf")
    plt.savefig(pdf_path, format='pdf', bbox_inches='tight')
    plt.close()
    print(f"✅ Saved: {pdf_path}")

# Generate and save circuits
for q in [4, 6, 8, 10, 12]:
    save_detailed_circuit(n_qubits=q, n_layers=2)

# Zip all PDFs
zip_filename = "quantum_circuits_pdf.zip"
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in os.listdir(output_dir):
        zipf.write(os.path.join(output_dir, file), file)

print(f"📦 All circuits zipped into: {zip_filename}")

# Create a download link in Kaggle
FileLink(zip_filename)
# Out:
# ✅ Saved: quantum_circuits_pdf/circuit_4qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_6qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_8qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_10qubits.pdf
# ✅ Saved: quantum_circuits_pdf/circuit_12qubits.pdf
# 📦 All circuits zipped into: quantum_circuits_pdf.zip
# /kaggle/working/quantum_circuits_pdf.zip
