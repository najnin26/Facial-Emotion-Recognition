# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

DATA_DIR='/kaggle/input/8-facial-expressions-for-yolo/9 Facial Expressions you need'
train = os.listdir(os.path.join(DATA_DIR,'train'))
test = os.listdir(os.path.join(DATA_DIR,'test'))
val=os.listdir(os.path.join(DATA_DIR,'valid'))
print(f'Train - {train}')
print(f'Test - {test}')
print(f'Val - {val}')
# Out:
# Train - ['labels', 'images']
# Test - ['labels', 'images']
# Val - ['labels', 'images']

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical

IMG_SIZE = 48
EMOTIONS = ['Happy', 'Sad', 'Angry', 'Surprised', 'Neutral', 'Disgusted', 'Fear', 'Sleepy', 'Contempt']  # update based on your labels
emotion_to_idx = {e: i for i, e in enumerate(EMOTIONS)}
idx_to_emotion = {i: e for i, e in enumerate(EMOTIONS)} # Add mapping from index to emotion

def load_data(folder_path):
    image_dir = os.path.join(folder_path, 'images')
    label_dir = os.path.join(folder_path, 'labels')

    images = []
    labels = []

    # Get list of label files
    label_files = sorted([f for f in os.listdir(label_dir) if f.endswith('.txt')])

    for label_fname in label_files:
        image_fname = label_fname.replace('.txt', '.jpg')
        image_path = os.path.join(image_dir, image_fname)
        label_path = os.path.join(label_dir, label_fname)

        # Check if the corresponding image file exists
        if not os.path.exists(image_path):
            print(f"Warning: Image file not found for label file {label_path}. Skipping.")
            continue

        # Load image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Warning: Could not read image file {image_path}. Skipping.")
            continue
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))  # Resize to 48×48
        images.append(img)

        # Load and parse label from YOLO format
        with open(label_path, 'r') as f:
            label_content = f.read().strip()
            # Assuming the first number in the line is the class ID
            try:
                class_id = int(label_content.split()[0])
                labels.append(class_id)
            except (ValueError, IndexError):
                print(f"Warning: Could not parse label from file {label_path}. Content: '{label_content}'. Skipping.")
                images.pop() # Remove the image if label parsing fails
                continue


    images = np.array(images)
    labels = np.array(labels)
    return images, labels
     

# Load full data from train folder
images, labels = load_data(os.path.join(DATA_DIR, 'test'))

# Normalize pixel values to be between 0 and 1
images = images / 255.0

# Reduce dataset size
n_train = 5000
n_test = 3000

train_images = images[:n_train]
train_labels = labels[:n_train]
test_images = images[-n_test:]
test_labels = labels[-n_test:]

# Add grayscale channel dimension: (N, 48, 48, 1)
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# One-hot encode the labels
train_labels_categorical = to_categorical(train_labels, num_classes=len(EMOTIONS))
test_labels_categorical = to_categorical(test_labels, num_classes=len(EMOTIONS))

# Final checks
print(f"Train images shape: {train_images.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Train labels shape: {train_labels_categorical.shape}")
print(f"Test labels shape: {test_labels_categorical.shape}")
# Out:
# 2025-07-30 04:45:44.227859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753850744.524131      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753850744.604877      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Train images shape: (1700, 48, 48, 1)
# Test images shape: (1700, 48, 48, 1)
# Train labels shape: (1700, 9)
# Test labels shape: (1700, 9)

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.42.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.42 (from pennylane)
#   Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (25.0)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.42->pennylane)
#   Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2.4.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.6.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pennylane) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pennylane) (2024.2.0)
# Downloading pennylane-0.42.1-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 44.6 MB/s eta 0:00:0000:0100:01
# Downloading autoray-0.7.2-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 37.4 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 63.1 MB/s eta 0:00:00:00:01
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.3 MB/s eta 0:00:00:00:01
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 10.2 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 77.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: appdirs, scipy-openblas32, autoray, diastatic-malt, rustworkx, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.2 diastatic-malt-2.15.2 pennylane-0.42.1 pennylane-lightning-0.42.0 rustworkx-0.16.0 scipy-openblas32-0.3.30.0.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Fix random seeds
np.random.seed(0)
tf.random.set_seed(0)

# Number of classes (for this dataset)
num_classes = len(EMOTIONS)

# Define qubit patch sizes
qubit_patch_shapes = {
    4: (2, 2),
    6: (3, 2),
    8: (4, 2),
    10: (5, 2),
    12: (4, 3),
}

# ------------------ Quantum Circuit Creation -------------------
def create_circuit(n_qubits, n_layers=1):
    dev = qml.device("default.qubit", wires=n_qubits)
    rand_params = np.random.uniform(high=2*np.pi, size=(n_layers, n_qubits))

    @qml.qnode(dev)
    def circuit(phi):
        # Encode classical data into qubits
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)
        RandomLayers(rand_params, wires=range(n_qubits))
        return [qml.expval(qml.PauliZ(j)) for j in range(n_qubits)]

    return circuit

# ------------------ Quantum Convolution -------------------
def quanv(image, circuit, patch_h, patch_w):
    out_h = (image.shape[0] - patch_h) // 2 + 1
    out_w = (image.shape[1] - patch_w) // 2 + 1
    n_qubits = patch_h * patch_w
    out = np.zeros((out_h, out_w, n_qubits))
    for j in range(0, image.shape[0] - patch_h + 1, 2):
        for k in range(0, image.shape[1] - patch_w + 1, 2):
            patch = image[j:j+patch_h, k:k+patch_w, 0].flatten()
            q_results = circuit(patch)
            out[j//2, k//2, :] = q_results
    return out

# ------------------ Classical Model -------------------
def build_model(input_shape, num_classes):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ------------------ Run for Multiple Qubits -------------------
results = {}
n_qubits=8 # Changed from list [6] to integer 6

print(f"\n=== Running for {n_qubits} Qubits ===")
patch_h, patch_w = qubit_patch_shapes[n_qubits]
circuit = create_circuit(n_qubits)

# Show quantum circuit diagram
print(f"\nQuantum Circuit for {n_qubits} Qubits:")
fig, ax = qml.draw_mpl(circuit)(np.random.rand(n_qubits))
plt.show()

# Quantum preprocessing
print("Quantum preprocessing (train)...")
q_train_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in train_images])
print("Quantum preprocessing (test)...")
q_test_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in test_images])
# Out:
# === Running for 8 Qubits ===
#
# Quantum Circuit for 8 Qubits:
# Quantum preprocessing (train)...
# Quantum preprocessing (test)...

# %%
# Train classical model
model = build_model(q_train_images.shape[1:], num_classes)
model.fit(q_train_images, train_labels, validation_data=(q_test_images, test_labels),
              epochs=800, batch_size=8, verbose=2)

# Predictions & evaluation
y_pred = np.argmax(model.predict(q_test_images), axis=1)

print(f"\nClassification Report ({n_qubits} Qubits):")
print(classification_report(test_labels, y_pred, target_names=EMOTIONS, labels=range(num_classes)))

    # Confusion Matrix
cm = confusion_matrix(test_labels, y_pred, labels=range(num_classes)) # Add labels parameter here as well
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=EMOTIONS, yticklabels=EMOTIONS)
plt.title(f"Confusion Matrix - {n_qubits} Qubits")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Accuracy
acc = model.evaluate(q_test_images, test_labels, verbose=0)[1]
print(f"Test Accuracy ({n_qubits} Qubits): {acc:.4f}")
results[n_qubits] = acc

# ------------------ Accuracy Comparison Plot -------------------
plt.figure(figsize=(8, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Quantum CNN Accuracy vs Number of Qubits (9-class Dataset)")
plt.xlabel("Number of Qubits")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

print("\n=== Final Accuracy Comparison ===")
for q, a in results.items():
    print(f"{q} Qubits: Accuracy = {a:.4f}")
# Out:
# Epoch 1/800
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 213/213 - 3s - 13ms/step - accuracy: 0.2000 - loss: 2.3037 - val_accuracy: 0.2724 - val_loss: 1.9766
# Epoch 2/800
# 213/213 - 1s - 6ms/step - accuracy: 0.2435 - loss: 1.9987 - val_accuracy: 0.3271 - val_loss: 1.9340
# Epoch 3/800
# 213/213 - 1s - 6ms/step - accuracy: 0.2835 - loss: 1.9112 - val_accuracy: 0.3482 - val_loss: 1.8077
# Epoch 4/800
# 213/213 - 1s - 6ms/step - accuracy: 0.2947 - loss: 1.8733 - val_accuracy: 0.3729 - val_loss: 1.7632
# Epoch 5/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3071 - loss: 1.8070 - val_accuracy: 0.3806 - val_loss: 1.6930
# Epoch 6/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3129 - loss: 1.7707 - val_accuracy: 0.3876 - val_loss: 1.6631
# Epoch 7/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3318 - loss: 1.7262 - val_accuracy: 0.4041 - val_loss: 1.6047
# Epoch 8/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3524 - loss: 1.6801 - val_accuracy: 0.4229 - val_loss: 1.5711
# Epoch 9/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3635 - loss: 1.6543 - val_accuracy: 0.4359 - val_loss: 1.4943
# Epoch 10/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3776 - loss: 1.5883 - val_accuracy: 0.4600 - val_loss: 1.4432
# Epoch 11/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3906 - loss: 1.5473 - val_accuracy: 0.4888 - val_loss: 1.3669
# Epoch 12/800
# 213/213 - 1s - 6ms/step - accuracy: 0.3947 - loss: 1.5441 - val_accuracy: 0.4900 - val_loss: 1.3794
# Epoch 13/800
# 213/213 - 1s - 7ms/step - accuracy: 0.3988 - loss: 1.5153 - val_accuracy: 0.5071 - val_loss: 1.2990
# Epoch 14/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4188 - loss: 1.4800 - val_accuracy: 0.5206 - val_loss: 1.2552
# Epoch 15/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4218 - loss: 1.4398 - val_accuracy: 0.5218 - val_loss: 1.2074
# Epoch 16/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4318 - loss: 1.4127 - val_accuracy: 0.5265 - val_loss: 1.2110
# Epoch 17/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4141 - loss: 1.4232 - val_accuracy: 0.5235 - val_loss: 1.1641
# Epoch 18/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4276 - loss: 1.3746 - val_accuracy: 0.5329 - val_loss: 1.1791
# Epoch 19/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4329 - loss: 1.3823 - val_accuracy: 0.5706 - val_loss: 1.0992
# Epoch 20/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4400 - loss: 1.3507 - val_accuracy: 0.5512 - val_loss: 1.1400
# Epoch 21/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4618 - loss: 1.3204 - val_accuracy: 0.5812 - val_loss: 1.0936
# Epoch 22/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4571 - loss: 1.2893 - val_accuracy: 0.5706 - val_loss: 1.0746
# Epoch 23/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4747 - loss: 1.2831 - val_accuracy: 0.5800 - val_loss: 1.0598
# Epoch 24/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4647 - loss: 1.2816 - val_accuracy: 0.5953 - val_loss: 1.0013
# Epoch 25/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4776 - loss: 1.2682 - val_accuracy: 0.6029 - val_loss: 1.0325
# Epoch 26/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4941 - loss: 1.2451 - val_accuracy: 0.6012 - val_loss: 1.0088
# Epoch 27/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4741 - loss: 1.2540 - val_accuracy: 0.6100 - val_loss: 1.0167
# Epoch 28/800
# 213/213 - 1s - 7ms/step - accuracy: 0.4929 - loss: 1.2033 - val_accuracy: 0.6371 - val_loss: 0.9225
# Epoch 29/800
# 213/213 - 1s - 6ms/step - accuracy: 0.4988 - loss: 1.2202 - val_accuracy: 0.5906 - val_loss: 1.0507
# Epoch 30/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5047 - loss: 1.1878 - val_accuracy: 0.6329 - val_loss: 0.9638
# Epoch 31/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5018 - loss: 1.2183 - val_accuracy: 0.6459 - val_loss: 0.9447
# Epoch 32/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5076 - loss: 1.1524 - val_accuracy: 0.6482 - val_loss: 0.9157
# Epoch 33/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5100 - loss: 1.1678 - val_accuracy: 0.6471 - val_loss: 0.9017
# Epoch 34/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5241 - loss: 1.1563 - val_accuracy: 0.6594 - val_loss: 0.8946
# Epoch 35/800
# 213/213 - 1s - 7ms/step - accuracy: 0.5188 - loss: 1.1178 - val_accuracy: 0.6588 - val_loss: 0.8682
# Epoch 36/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5347 - loss: 1.1225 - val_accuracy: 0.6706 - val_loss: 0.8842
# Epoch 37/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5288 - loss: 1.1477 - val_accuracy: 0.6676 - val_loss: 0.8800
# Epoch 38/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5282 - loss: 1.1272 - val_accuracy: 0.6859 - val_loss: 0.8099
# Epoch 39/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5476 - loss: 1.0970 - val_accuracy: 0.6976 - val_loss: 0.8397
# Epoch 40/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5429 - loss: 1.0814 - val_accuracy: 0.6900 - val_loss: 0.8360
# Epoch 41/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5365 - loss: 1.1285 - val_accuracy: 0.6559 - val_loss: 0.8467
# Epoch 42/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5388 - loss: 1.0965 - val_accuracy: 0.6894 - val_loss: 0.8569
# Epoch 43/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5347 - loss: 1.1347 - val_accuracy: 0.6935 - val_loss: 0.7936
# Epoch 44/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5382 - loss: 1.0835 - val_accuracy: 0.7047 - val_loss: 0.7933
# Epoch 45/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5453 - loss: 1.1236 - val_accuracy: 0.6576 - val_loss: 0.9042
# Epoch 46/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5518 - loss: 1.0781 - val_accuracy: 0.6829 - val_loss: 0.8553
# Epoch 47/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5506 - loss: 1.0845 - val_accuracy: 0.7071 - val_loss: 0.8154
# Epoch 48/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5447 - loss: 1.0772 - val_accuracy: 0.6806 - val_loss: 0.8419
# Epoch 49/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5541 - loss: 1.0524 - val_accuracy: 0.7153 - val_loss: 0.7643
# Epoch 50/800
# 213/213 - 1s - 7ms/step - accuracy: 0.5629 - loss: 1.0218 - val_accuracy: 0.6700 - val_loss: 0.8162
# Epoch 51/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5441 - loss: 1.0849 - val_accuracy: 0.6924 - val_loss: 0.7727
# Epoch 52/800
# 213/213 - 1s - 7ms/step - accuracy: 0.5765 - loss: 1.0215 - val_accuracy: 0.7100 - val_loss: 0.7805
# Epoch 53/800
# 213/213 - 1s - 7ms/step - accuracy: 0.5518 - loss: 1.0461 - val_accuracy: 0.7235 - val_loss: 0.7591
# Epoch 54/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5588 - loss: 1.0259 - val_accuracy: 0.7041 - val_loss: 0.7866
# Epoch 55/800
# 213/213 - 1s - 7ms/step - accuracy: 0.5776 - loss: 1.0071 - val_accuracy: 0.6953 - val_loss: 0.8292
# Epoch 56/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5694 - loss: 1.0297 - val_accuracy: 0.7071 - val_loss: 0.8056
# Epoch 57/800
# 213/213 - 1s - 7ms/step - accuracy: 0.5788 - loss: 0.9975 - val_accuracy: 0.7035 - val_loss: 0.7498
# Epoch 58/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5653 - loss: 1.0401 - val_accuracy: 0.7024 - val_loss: 0.7628
# Epoch 59/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5624 - loss: 1.0261 - val_accuracy: 0.6871 - val_loss: 0.8211
# Epoch 60/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5676 - loss: 1.0290 - val_accuracy: 0.6794 - val_loss: 0.8794
# Epoch 61/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5641 - loss: 1.0391 - val_accuracy: 0.6971 - val_loss: 0.8389
# Epoch 62/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5629 - loss: 1.0375 - val_accuracy: 0.6988 - val_loss: 0.8250
# Epoch 63/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5894 - loss: 0.9692 - val_accuracy: 0.7229 - val_loss: 0.7295
# Epoch 64/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5888 - loss: 0.9882 - val_accuracy: 0.7265 - val_loss: 0.7297
# Epoch 65/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5824 - loss: 0.9837 - val_accuracy: 0.7153 - val_loss: 0.7597
# Epoch 66/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5865 - loss: 1.0130 - val_accuracy: 0.7253 - val_loss: 0.7476
# Epoch 67/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5735 - loss: 1.0086 - val_accuracy: 0.6694 - val_loss: 0.9268
# Epoch 68/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5776 - loss: 1.0236 - val_accuracy: 0.6941 - val_loss: 0.8009
# Epoch 69/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5706 - loss: 1.0325 - val_accuracy: 0.7035 - val_loss: 0.7587
# Epoch 70/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5847 - loss: 0.9882 - val_accuracy: 0.7306 - val_loss: 0.7001
# Epoch 71/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5706 - loss: 0.9874 - val_accuracy: 0.7200 - val_loss: 0.7623
# Epoch 72/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5900 - loss: 0.9733 - val_accuracy: 0.7088 - val_loss: 0.7626
# Epoch 73/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5747 - loss: 1.0238 - val_accuracy: 0.7053 - val_loss: 0.7673
# Epoch 74/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5429 - loss: 1.0627 - val_accuracy: 0.7406 - val_loss: 0.6820
# Epoch 75/800
# 213/213 - 1s - 6ms/step - accuracy: 0.6065 - loss: 0.9278 - val_accuracy: 0.7271 - val_loss: 0.7049
# Epoch 76/800
# 213/213 - 1s - 6ms/step - accuracy: 0.6053 - loss: 0.9306 - val_accuracy: 0.7094 - val_loss: 0.7852
# Epoch 77/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5847 - loss: 0.9702 - val_accuracy: 0.7029 - val_loss: 0.7664
# Epoch 78/800
# 213/213 - 1s - 6ms/step - accuracy: 0.5900 - loss: 0.9876 - val_accuracy: 0.7171 - val_loss: 0.7538
# Epoch 79/800
# 213/213 - 1s - 6ms/step - accuracy: 0.
800
# 213/213 - 1s - 6ms/step - accuracy: 0.7076 - loss: 0.6693 - val_accuracy: 0.9035 - val_loss: 0.2701
# Epoch 754/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7147 - loss: 0.6601 - val_accuracy: 0.9147 - val_loss: 0.2628
# Epoch 755/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7041 - loss: 0.6747 - val_accuracy: 0.9012 - val_loss: 0.2742
# Epoch 756/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7182 - loss: 0.6355 - val_accuracy: 0.9159 - val_loss: 0.2565
# Epoch 757/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7359 - loss: 0.6110 - val_accuracy: 0.9012 - val_loss: 0.2646
# Epoch 758/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7259 - loss: 0.6308 - val_accuracy: 0.9071 - val_loss: 0.2544
# Epoch 759/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7159 - loss: 0.6511 - val_accuracy: 0.9171 - val_loss: 0.2610
# Epoch 760/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7388 - loss: 0.6192 - val_accuracy: 0.8806 - val_loss: 0.4079
# Epoch 761/800
# 213/213 - 1s - 7ms/step - accuracy: 0.6988 - loss: 0.7314 - val_accuracy: 0.9012 - val_loss: 0.2931
# Epoch 762/800
# 213/213 - 1s - 7ms/step - accuracy: 0.7247 - loss: 0.6390 - val_accuracy: 0.9065 - val_loss: 0.2691
# Epoch 763/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7188 - loss: 0.6515 - val_accuracy: 0.9094 - val_loss: 0.2712
# Epoch 764/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7394 - loss: 0.6111 - val_accuracy: 0.8953 - val_loss: 0.2969
# Epoch 765/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7006 - loss: 0.6865 - val_accuracy: 0.9147 - val_loss: 0.2810
# Epoch 766/800
# 213/213 - 1s - 7ms/step - accuracy: 0.7218 - loss: 0.6756 - val_accuracy: 0.8965 - val_loss: 0.3189
# Epoch 767/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7247 - loss: 0.6599 - val_accuracy: 0.8941 - val_loss: 0.3059
# Epoch 768/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7176 - loss: 0.6755 - val_accuracy: 0.9047 - val_loss: 0.2834
# Epoch 769/800
# 213/213 - 1s - 7ms/step - accuracy: 0.7094 - loss: 0.6703 - val_accuracy: 0.9094 - val_loss: 0.2805
# Epoch 770/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7212 - loss: 0.6453 - val_accuracy: 0.8894 - val_loss: 0.2975
# Epoch 771/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7171 - loss: 0.6604 - val_accuracy: 0.9088 - val_loss: 0.2544
# Epoch 772/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7218 - loss: 0.6429 - val_accuracy: 0.9012 - val_loss: 0.3026
# Epoch 773/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7324 - loss: 0.6328 - val_accuracy: 0.8941 - val_loss: 0.2987
# Epoch 774/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7324 - loss: 0.6234 - val_accuracy: 0.9071 - val_loss: 0.2594
# Epoch 775/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7118 - loss: 0.6852 - val_accuracy: 0.8865 - val_loss: 0.3583
# Epoch 776/800
# 213/213 - 1s - 6ms/step - accuracy: 0.6918 - loss: 0.7411 - val_accuracy: 0.8759 - val_loss: 0.3490
# Epoch 777/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7224 - loss: 0.6538 - val_accuracy: 0.9071 - val_loss: 0.2708
# Epoch 778/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7424 - loss: 0.6179 - val_accuracy: 0.9188 - val_loss: 0.2565
# Epoch 779/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7153 - loss: 0.6862 - val_accuracy: 0.9018 - val_loss: 0.2989
# Epoch 780/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7224 - loss: 0.6504 - val_accuracy: 0.9165 - val_loss: 0.2575
# Epoch 781/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7312 - loss: 0.6271 - val_accuracy: 0.9082 - val_loss: 0.2768
# Epoch 782/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7318 - loss: 0.6434 - val_accuracy: 0.8988 - val_loss: 0.2863
# Epoch 783/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7159 - loss: 0.6868 - val_accuracy: 0.9053 - val_loss: 0.2673
# Epoch 784/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7235 - loss: 0.6757 - val_accuracy: 0.8982 - val_loss: 0.2828
# Epoch 785/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7200 - loss: 0.6479 - val_accuracy: 0.9124 - val_loss: 0.2548
# Epoch 786/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7006 - loss: 0.6986 - val_accuracy: 0.9012 - val_loss: 0.2891
# Epoch 787/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7124 - loss: 0.6727 - val_accuracy: 0.9041 - val_loss: 0.2859
# Epoch 788/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7206 - loss: 0.6703 - val_accuracy: 0.9000 - val_loss: 0.3009
# Epoch 789/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7294 - loss: 0.6487 - val_accuracy: 0.9082 - val_loss: 0.2546
# Epoch 790/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7259 - loss: 0.6326 - val_accuracy: 0.9129 - val_loss: 0.2493
# Epoch 791/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7188 - loss: 0.6278 - val_accuracy: 0.9112 - val_loss: 0.2661
# Epoch 792/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7518 - loss: 0.6003 - val_accuracy: 0.9118 - val_loss: 0.2627
# Epoch 793/800
# 213/213 - 1s - 7ms/step - accuracy: 0.7271 - loss: 0.6187 - val_accuracy: 0.9076 - val_loss: 0.2881
# Epoch 794/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7347 - loss: 0.6243 - val_accuracy: 0.9118 - val_loss: 0.2611
# Epoch 795/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7165 - loss: 0.6572 - val_accuracy: 0.9047 - val_loss: 0.3004
# Epoch 796/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7106 - loss: 0.6585 - val_accuracy: 0.9153 - val_loss: 0.2788
# Epoch 797/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7353 - loss: 0.6226 - val_accuracy: 0.9235 - val_loss: 0.2394
# Epoch 798/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7206 - loss: 0.6698 - val_accuracy: 0.9065 - val_loss: 0.2653
# Epoch 799/800
# 213/213 - 1s - 7ms/step - accuracy: 0.7341 - loss: 0.6088 - val_accuracy: 0.9176 - val_loss: 0.2484
# Epoch 800/800
# 213/213 - 1s - 6ms/step - accuracy: 0.7306 - loss: 0.6258 - val_accuracy: 0.9006 - val_loss: 0.3110
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report (8 Qubits):
#               precision    recall  f1-score   support
#
#        Happy       0.75      0.98      0.85       297
#          Sad       0.97      0.50      0.66        68
#        Angry       0.92      0.90      0.91        98
#    Surprised       0.99      0.74      0.85       144
#      Neutral       0.94      0.96      0.95       407
#    Disgusted       0.88      0.88      0.88       136
#         Fear       1.00      0.94      0.97       298
#       Sleepy       1.00      0.91      0.95        33
#     Contempt       0.89      0.87      0.88       219
#
#     accuracy                           0.90      1700
#    macro avg       0.93      0.85      0.88      1700
# weighted avg       0.91      0.90      0.90      1700
# Test Accuracy (8 Qubits): 0.9006
# === Final Accuracy Comparison ===
# 8 Qubits: Accuracy = 0.9006

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt

# Function to create and display detailed quantum circuits
def show_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    # Random parameters for encoding & random layers
    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)  # Sample classical input for encoding

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding using RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Apply random entangling layers
        RandomLayers(rand_params, wires=range(n_qubits))

        # Measurement
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw circuit
    fig, ax = qml.draw_mpl(circuit)(sample_inputs)
    plt.title(f"Quantum Circuit with {n_qubits} Qubits & {n_layers} Random Layers")
    plt.show()

# Show circuits for 4, 6, 8, 10, 12 qubits
for q in [4, 6, 8, 10, 12]:
    show_detailed_circuit(n_qubits=q, n_layers=2)
