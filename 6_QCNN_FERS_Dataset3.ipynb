# %%
# !pip install kagglehub

import kagglehub

# Download latest version
path = kagglehub.dataset_download("aklimarimi/8-facial-expressions-for-yolo")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (0.3.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2025.7.14)
# Path to dataset files: /kaggle/input/8-facial-expressions-for-yolo

# %%
import os

# Constants
IMG_SIZE = 48
# DATA_DIR = '/kaggle/input/8-facial-expressions-for-yolo/9 Facial Expressions you need/'
DATA_DIR = os.path.join(path, '9 Facial Expressions you need') # Use the path returned by kagglehub.dataset_download

# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline


train = os.listdir(os.path.join(DATA_DIR,'train'))
test = os.listdir(os.path.join(DATA_DIR,'test'))
val=os.listdir(os.path.join(DATA_DIR,'valid'))
print(f'Train - {train}')
print(f'Test - {test}')
print(f'Val - {val}')
# Out:
# Train - ['labels', 'images']
# Test - ['labels', 'images']
# Val - ['labels', 'images']

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical

IMG_SIZE = 48
EMOTIONS = ['Happy', 'Sad', 'Angry', 'Surprised', 'Neutral', 'Disgusted', 'Fear', 'Sleepy', 'Contempt']  # update based on your labels
emotion_to_idx = {e: i for i, e in enumerate(EMOTIONS)}
idx_to_emotion = {i: e for i, e in enumerate(EMOTIONS)} # Add mapping from index to emotion

def load_data(folder_path):
    image_dir = os.path.join(folder_path, 'images')
    label_dir = os.path.join(folder_path, 'labels')

    images = []
    labels = []

    # Get list of label files
    label_files = sorted([f for f in os.listdir(label_dir) if f.endswith('.txt')])

    for label_fname in label_files:
        image_fname = label_fname.replace('.txt', '.jpg')
        image_path = os.path.join(image_dir, image_fname)
        label_path = os.path.join(label_dir, label_fname)

        # Check if the corresponding image file exists
        if not os.path.exists(image_path):
            print(f"Warning: Image file not found for label file {label_path}. Skipping.")
            continue

        # Load image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Warning: Could not read image file {image_path}. Skipping.")
            continue
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))  # Resize to 48×48
        images.append(img)

        # Load and parse label from YOLO format
        with open(label_path, 'r') as f:
            label_content = f.read().strip()
            # Assuming the first number in the line is the class ID
            try:
                class_id = int(label_content.split()[0])
                labels.append(class_id)
            except (ValueError, IndexError):
                print(f"Warning: Could not parse label from file {label_path}. Content: '{label_content}'. Skipping.")
                images.pop() # Remove the image if label parsing fails
                continue


    images = np.array(images)
    labels = np.array(labels)
    return images, labels

# %%
# Load full data from train folder
images, labels = load_data(os.path.join(DATA_DIR, 'test'))

# Normalize pixel values to be between 0 and 1
images = images / 255.0

# Reduce dataset size
n_train = 5000
n_test = 3000

train_images = images[:n_train]
train_labels = labels[:n_train]
test_images = images[-n_test:]
test_labels = labels[-n_test:]

# Add grayscale channel dimension: (N, 48, 48, 1)
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# One-hot encode the labels
train_labels_categorical = to_categorical(train_labels, num_classes=len(EMOTIONS))
test_labels_categorical = to_categorical(test_labels, num_classes=len(EMOTIONS))

# Final checks
print(f"Train images shape: {train_images.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Train labels shape: {train_labels_categorical.shape}")
print(f"Test labels shape: {test_labels_categorical.shape}")
# Out:
# Train images shape: (1700, 48, 48, 1)
# Test images shape: (1700, 48, 48, 1)
# Train labels shape: (1700, 9)
# Test labels shape: (1700, 9)

# %%
# !pip install pennylane
# Out:
# Requirement already satisfied: pennylane in /usr/local/lib/python3.11/dist-packages (0.42.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Requirement already satisfied: rustworkx>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.16.0)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray>=0.6.11 in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.7.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Requirement already satisfied: pennylane-lightning>=0.42 in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.42.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (25.0)
# Requirement already satisfied: diastatic-malt in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.15.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.0.2)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from pennylane-lightning>=0.42->pennylane) (0.3.30.0.2)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.7.14)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Fix random seeds
np.random.seed(0)
tf.random.set_seed(0)

# Number of classes (for this dataset)
num_classes = len(EMOTIONS)

# Define qubit patch sizes
qubit_patch_shapes = {
    4: (2, 2),
    6: (3, 2),
    8: (4, 2),
    10: (5, 2),
    12: (4, 3),
}

# ------------------ Quantum Circuit Creation -------------------
def create_circuit(n_qubits, n_layers=1):
    dev = qml.device("default.qubit", wires=n_qubits)
    rand_params = np.random.uniform(high=2*np.pi, size=(n_layers, n_qubits))

    @qml.qnode(dev)
    def circuit(phi):
        # Encode classical data into qubits
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)
        RandomLayers(rand_params, wires=range(n_qubits))
        return [qml.expval(qml.PauliZ(j)) for j in range(n_qubits)]

    return circuit

# ------------------ Quantum Convolution -------------------
def quanv(image, circuit, patch_h, patch_w):
    out_h = (image.shape[0] - patch_h) // 2 + 1
    out_w = (image.shape[1] - patch_w) // 2 + 1
    n_qubits = patch_h * patch_w
    out = np.zeros((out_h, out_w, n_qubits))
    for j in range(0, image.shape[0] - patch_h + 1, 2):
        for k in range(0, image.shape[1] - patch_w + 1, 2):
            patch = image[j:j+patch_h, k:k+patch_w, 0].flatten()
            q_results = circuit(patch)
            out[j//2, k//2, :] = q_results
    return out

# ------------------ Classical Model -------------------
def build_model(input_shape, num_classes):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ------------------ Run for Multiple Qubits -------------------
results = {}
n_qubits=6 # Changed from list [6] to integer 6

print(f"\n=== Running for {n_qubits} Qubits ===")
patch_h, patch_w = qubit_patch_shapes[n_qubits]
circuit = create_circuit(n_qubits)

# Show quantum circuit diagram
print(f"\nQuantum Circuit for {n_qubits} Qubits:")
fig, ax = qml.draw_mpl(circuit)(np.random.rand(n_qubits))
plt.show()

# Quantum preprocessing
print("Quantum preprocessing (train)...")
q_train_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in train_images])
print("Quantum preprocessing (test)...")
q_test_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in test_images])
# Out:
# === Running for 6 Qubits ===
#
# Quantum Circuit for 6 Qubits:
# Quantum preprocessing (train)...
# Quantum preprocessing (test)...

# %%
# Train classical model
model = build_model(q_train_images.shape[1:], num_classes)
model.fit(q_train_images, train_labels, validation_data=(q_test_images, test_labels),
              epochs=600, batch_size=8, verbose=2)

# Predictions & evaluation
y_pred = np.argmax(model.predict(q_test_images), axis=1)

print(f"\nClassification Report ({n_qubits} Qubits):")
print(classification_report(test_labels, y_pred, target_names=EMOTIONS, labels=range(num_classes)))

    # Confusion Matrix
cm = confusion_matrix(test_labels, y_pred, labels=range(num_classes)) # Add labels parameter here as well
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=EMOTIONS, yticklabels=EMOTIONS)
plt.title(f"Confusion Matrix - {n_qubits} Qubits")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Accuracy
acc = model.evaluate(q_test_images, test_labels, verbose=0)[1]
print(f"Test Accuracy ({n_qubits} Qubits): {acc:.4f}")
results[n_qubits] = acc

# ------------------ Accuracy Comparison Plot -------------------
plt.figure(figsize=(8, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Quantum CNN Accuracy vs Number of Qubits (9-class Dataset)")
plt.xlabel("Number of Qubits")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

print("\n=== Final Accuracy Comparison ===")
for q, a in results.items():
    print(f"{q} Qubits: Accuracy = {a:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/600
# 213/213 - 4s - 20ms/step - accuracy: 0.2194 - loss: 2.2142 - val_accuracy: 0.2735 - val_loss: 1.9548
# Epoch 2/600
# 213/213 - 2s - 10ms/step - accuracy: 0.2571 - loss: 1.9588 - val_accuracy: 0.3106 - val_loss: 1.8484
# Epoch 3/600
# 213/213 - 3s - 13ms/step - accuracy: 0.2706 - loss: 1.8857 - val_accuracy: 0.3159 - val_loss: 1.8076
# Epoch 4/600
# 213/213 - 2s - 8ms/step - accuracy: 0.3006 - loss: 1.8406 - val_accuracy: 0.3282 - val_loss: 1.7323
# Epoch 5/600
# 213/213 - 3s - 14ms/step - accuracy: 0.3076 - loss: 1.7615 - val_accuracy: 0.3553 - val_loss: 1.6636
# Epoch 6/600
# 213/213 - 2s - 9ms/step - accuracy: 0.3324 - loss: 1.7214 - val_accuracy: 0.3818 - val_loss: 1.6377
# Epoch 7/600
# 213/213 - 3s - 13ms/step - accuracy: 0.3329 - loss: 1.6971 - val_accuracy: 0.3853 - val_loss: 1.6312
# Epoch 8/600
# 213/213 - 2s - 9ms/step - accuracy: 0.3624 - loss: 1.6354 - val_accuracy: 0.4212 - val_loss: 1.5348
# Epoch 9/600
# 213/213 - 3s - 12ms/step - accuracy: 0.3541 - loss: 1.6297 - val_accuracy: 0.4541 - val_loss: 1.4843
# Epoch 10/600
# 213/213 - 3s - 13ms/step - accuracy: 0.3824 - loss: 1.5706 - val_accuracy: 0.4500 - val_loss: 1.4825
# Epoch 11/600
# 213/213 - 2s - 9ms/step - accuracy: 0.3959 - loss: 1.5331 - val_accuracy: 0.4794 - val_loss: 1.4428
# Epoch 12/600
# 213/213 - 2s - 11ms/step - accuracy: 0.4018 - loss: 1.5316 - val_accuracy: 0.5141 - val_loss: 1.3692
# Epoch 13/600
# 213/213 - 3s - 13ms/step - accuracy: 0.4294 - loss: 1.4553 - val_accuracy: 0.5235 - val_loss: 1.3082
# Epoch 14/600
# 213/213 - 2s - 8ms/step - accuracy: 0.4276 - loss: 1.4553 - val_accuracy: 0.5376 - val_loss: 1.3459
# Epoch 15/600
# 213/213 - 3s - 15ms/step - accuracy: 0.4435 - loss: 1.4216 - val_accuracy: 0.5624 - val_loss: 1.2406
# Epoch 16/600
# 213/213 - 2s - 8ms/step - accuracy: 0.4494 - loss: 1.3644 - val_accuracy: 0.5841 - val_loss: 1.1905
# Epoch 17/600
# 213/213 - 2s - 7ms/step - accuracy: 0.4682 - loss: 1.3509 - val_accuracy: 0.5824 - val_loss: 1.1848
# Epoch 18/600
# 213/213 - 3s - 13ms/step - accuracy: 0.4929 - loss: 1.3054 - val_accuracy: 0.5994 - val_loss: 1.1269
# Epoch 19/600
# 213/213 - 2s - 12ms/step - accuracy: 0.4782 - loss: 1.3051 - val_accuracy: 0.6106 - val_loss: 1.0942
# Epoch 20/600
# 213/213 - 2s - 9ms/step - accuracy: 0.4735 - loss: 1.2863 - val_accuracy: 0.6265 - val_loss: 1.0479
# Epoch 21/600
# 213/213 - 3s - 13ms/step - accuracy: 0.5088 - loss: 1.2456 - val_accuracy: 0.6412 - val_loss: 1.0462
# Epoch 22/600
# 213/213 - 2s - 9ms/step - accuracy: 0.5024 - loss: 1.2365 - val_accuracy: 0.6529 - val_loss: 0.9908
# Epoch 23/600
# 213/213 - 2s - 11ms/step - accuracy: 0.5282 - loss: 1.1938 - val_accuracy: 0.6288 - val_loss: 1.0143
# Epoch 24/600
# 213/213 - 2s - 9ms/step - accuracy: 0.5218 - loss: 1.1853 - val_accuracy: 0.6482 - val_loss: 0.9844
# Epoch 25/600
# 213/213 - 3s - 12ms/step - accuracy: 0.5324 - loss: 1.1648 - val_accuracy: 0.6429 - val_loss: 0.9804
# Epoch 26/600
# 213/213 - 3s - 15ms/step - accuracy: 0.5435 - loss: 1.1350 - val_accuracy: 0.6418 - val_loss: 0.9456
# Epoch 27/600
# 213/213 - 2s - 9ms/step - accuracy: 0.5176 - loss: 1.1678 - val_accuracy: 0.6724 - val_loss: 0.8861
# Epoch 28/600
# 213/213 - 2s - 9ms/step - accuracy: 0.5547 - loss: 1.1238 - val_accuracy: 0.6924 - val_loss: 0.8656
# Epoch 29/600
# 213/213 - 3s - 12ms/step - accuracy: 0.5571 - loss: 1.0588 - val_accuracy: 0.6806 - val_loss: 0.8579
# Epoch 30/600
# 213/213 - 2s - 11ms/step - accuracy: 0.5553 - loss: 1.0843 - val_accuracy: 0.6541 - val_loss: 0.9507
# Epoch 31/600
# 213/213 - 3s - 14ms/step - accuracy: 0.5694 - loss: 1.0543 - val_accuracy: 0.6788 - val_loss: 0.8836
# Epoch 32/600
# 213/213 - 2s - 10ms/step - accuracy: 0.5812 - loss: 1.0431 - val_accuracy: 0.6882 - val_loss: 0.8287
# Epoch 33/600
# 213/213 - 2s - 10ms/step - accuracy: 0.5741 - loss: 1.0503 - val_accuracy: 0.7318 - val_loss: 0.7923
# Epoch 34/600
# 213/213 - 3s - 12ms/step - accuracy: 0.5953 - loss: 0.9914 - val_accuracy: 0.7135 - val_loss: 0.7734
# Epoch 35/600
# 213/213 - 2s - 8ms/step - accuracy: 0.5906 - loss: 0.9947 - val_accuracy: 0.7471 - val_loss: 0.7511
# Epoch 36/600
# 213/213 - 2s - 7ms/step - accuracy: 0.6076 - loss: 0.9729 - val_accuracy: 0.7476 - val_loss: 0.7554
# Epoch 37/600
# 213/213 - 3s - 16ms/step - accuracy: 0.5959 - loss: 0.9933 - val_accuracy: 0.7376 - val_loss: 0.7511
# Epoch 38/600
# 213/213 - 2s - 8ms/step - accuracy: 0.6129 - loss: 0.9271 - val_accuracy: 0.7571 - val_loss: 0.7102
# Epoch 39/600
# 213/213 - 2s - 9ms/step - accuracy: 0.6106 - loss: 0.9489 - val_accuracy: 0.7618 - val_loss: 0.6937
# Epoch 40/600
# 213/213 - 3s - 12ms/step - accuracy: 0.5912 - loss: 0.9926 - val_accuracy: 0.7806 - val_loss: 0.6853
# Epoch 41/600
# 213/213 - 2s - 11ms/step - accuracy: 0.6135 - loss: 0.9513 - val_accuracy: 0.7765 - val_loss: 0.6564
# Epoch 42/600
# 213/213 - 3s - 14ms/step - accuracy: 0.6100 - loss: 0.9107 - val_accuracy: 0.7676 - val_loss: 0.6868
# Epoch 43/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6294 - loss: 0.8902 - val_accuracy: 0.7724 - val_loss: 0.6810
# Epoch 44/600
# 213/213 - 2s - 11ms/step - accuracy: 0.6282 - loss: 0.9404 - val_accuracy: 0.7759 - val_loss: 0.6394
# Epoch 45/600
# 213/213 - 2s - 8ms/step - accuracy: 0.6353 - loss: 0.9099 - val_accuracy: 0.7882 - val_loss: 0.6096
# Epoch 46/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6394 - loss: 0.8762 - val_accuracy: 0.7871 - val_loss: 0.6061
# Epoch 47/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6376 - loss: 0.8856 - val_accuracy: 0.7859 - val_loss: 0.6425
# Epoch 48/600
# 213/213 - 3s - 13ms/step - accuracy: 0.6594 - loss: 0.8478 - val_accuracy: 0.7729 - val_loss: 0.6462
# Epoch 49/600
# 213/213 - 2s - 10ms/step - accuracy: 0.6647 - loss: 0.8338 - val_accuracy: 0.7924 - val_loss: 0.6057
# Epoch 50/600
# 213/213 - 2s - 8ms/step - accuracy: 0.6571 - loss: 0.8231 - val_accuracy: 0.7971 - val_loss: 0.6006
# Epoch 51/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6606 - loss: 0.8493 - val_accuracy: 0.8118 - val_loss: 0.5583
# Epoch 52/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6576 - loss: 0.8562 - val_accuracy: 0.8165 - val_loss: 0.5746
# Epoch 53/600
# 213/213 - 3s - 14ms/step - accuracy: 0.6635 - loss: 0.8295 - val_accuracy: 0.8106 - val_loss: 0.5705
# Epoch 54/600
# 213/213 - 2s - 9ms/step - accuracy: 0.6565 - loss: 0.8832 - val_accuracy: 0.7806 - val_loss: 0.6395
# Epoch 55/600
# 213/213 - 2s - 8ms/step - accuracy: 0.6653 - loss: 0.8287 - val_accuracy: 0.8094 - val_loss: 0.5894
# Epoch 56/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6606 - loss: 0.8117 - val_accuracy: 0.8300 - val_loss: 0.5474
# Epoch 57/600
# 213/213 - 2s - 11ms/step - accuracy: 0.6824 - loss: 0.7801 - val_accuracy: 0.8141 - val_loss: 0.5411
# Epoch 58/600
# 213/213 - 2s - 11ms/step - accuracy: 0.6676 - loss: 0.7936 - val_accuracy: 0.8159 - val_loss: 0.5245
# Epoch 59/600
# 213/213 - 2s - 9ms/step - accuracy: 0.6865 - loss: 0.7860 - val_accuracy: 0.8247 - val_loss: 0.5288
# Epoch 60/600
# 213/213 - 2s - 9ms/step - accuracy: 0.6700 - loss: 0.7974 - val_accuracy: 0.8212 - val_loss: 0.5371
# Epoch 61/600
# 213/213 - 2s - 9ms/step - accuracy: 0.6924 - loss: 0.7668 - val_accuracy: 0.8429 - val_loss: 0.4757
# Epoch 62/600
# 213/213 - 2s - 11ms/step - accuracy: 0.6853 - loss: 0.8013 - val_accuracy: 0.8194 - val_loss: 0.5233
# Epoch 63/600
# 213/213 - 2s - 8ms/step - accuracy: 0.6894 - loss: 0.7795 - val_accuracy: 0.8194 - val_loss: 0.5350
# Epoch 64/600
# 213/213 - 4s - 18ms/step - accuracy: 0.6653 - loss: 0.8054 - val_accuracy: 0.8265 - val_loss: 0.4912
# Epoch 65/600
# 213/213 - 4s - 18ms/step - accuracy: 0.6853 - loss: 0.7576 - val_accuracy: 0.8529 - val_loss: 0.4467
# Epoch 66/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6988 - loss: 0.7540 - val_accuracy: 0.8329 - val_loss: 0.4844
# Epoch 67/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7012 - loss: 0.7318 - val_accuracy: 0.8641 - val_loss: 0.4303
# Epoch 68/600
# 213/213 - 4s - 16ms/step - accuracy: 0.7024 - loss: 0.7573 - val_accuracy: 0.8682 - val_loss: 0.4191
# Epoch 69/600
# 213/213 - 4s - 19ms/step - accuracy: 0.6853 - loss: 0.7674 - val_accuracy: 0.8506 - val_loss: 0.4543
# Epoch 70/600
# 213/213 - 2s - 9ms/step - accuracy: 0.6953 - loss: 0.7760 - val_accuracy: 0.8559 - val_loss: 0.4690
# Epoch 71/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6935 - loss: 0.7469 - val_accuracy: 0.8353 - val_loss: 0.4883
# Epoch 72/600
# 213/213 - 3s - 12ms/step - accuracy: 0.6988 - loss: 0.7511 - val_accuracy: 0.8335 - val_loss: 0.5057
# Epoch 73/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7059 - loss: 0.7356 - val_accuracy: 0.8371 - val_loss: 0.5144
# Epoch 74/600
# 213/213 - 2s - 11ms/step - accuracy: 0.6788 - loss: 0.7702 - val_accuracy: 0.8300 - val_loss: 0.5019
# Epoch 75/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7100 - loss: 0.7350 - val_accuracy: 0.8153 - val_loss: 0.5274
# Epoch 76/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7124 - loss: 0.6992 - val_accuracy: 0.8535 - val_loss: 0.4542
# Epoch 77/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7194 - loss: 0.6785 - val_accuracy: 0.8853 - val_loss: 0.3851
# Epoch 78/600
# 213/213 - 3s - 14ms/step - accuracy: 0.7276 - loss: 0.6684 - val_accuracy: 0.8647 - val_loss: 0.4295
# Epoch 79/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7100 - loss: 0.7102 - val_accuracy: 0.8276 - val_loss: 0.4882
# Epoch 80/600
# 213/213 - 3s - 13ms/step - accuracy: 0.6971 - loss: 0.7246 - val_accuracy: 0.8653 - val_loss: 0.4275
# Epoch 81/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7135 - loss: 0.7516 - val_accuracy: 0.8206 - val_loss: 0.4900
# Epoch 82/600
# 213/213 - 2s - 8ms/step - accuracy: 0.6965 - loss: 0.7462 - val_accuracy: 0.8565 - val_loss: 0.4332
# Epoch 83/600
# 213/213 - 4s - 18ms/step - accuracy: 0.7112 - loss: 0.7126 - val_accuracy: 0.8765 - val_loss: 0.3633
# Epoch 84/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7176 - loss: 0.7230 - val_accuracy: 0.8676 - val_loss: 0.4233
# Epoch 85/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7176 - loss: 0.7117 - val_accuracy: 0.8912 - val_loss: 0.3665
# Epoch 86/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7265 - loss: 0.6706 - val_accuracy: 0.8847 - val_loss: 0.3601
# Epoch 87/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7306 - loss: 0.6757 - val_accuracy: 0.8653 - val_loss: 0.4203
# Epoch 88/600
# 213/213 - 3s - 15ms/step - accuracy: 0.7306 - loss: 0.6932 - val_accuracy: 0.8782 - val_loss: 0.3854
# Epoch 89/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7153 - loss: 0.7154 - val_accuracy: 0.8865 - val_loss: 0.3834
# Epoch 90/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7441 - loss: 0.6641 - val_accuracy: 0.8835 - val_loss: 0.3905
# Epoch 91/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7259 - loss: 0.6683 - val_accuracy: 0.8906 - val_loss: 0.3895
# Epoch 92/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7300 - loss: 0.6842 - val_accuracy: 0.8888 - val_loss: 0.3568
# Epoch 93/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7247 - loss: 0.6846 - val_accuracy: 0.8824 - val_loss: 0.3661
# Epoch 94/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7535 - loss: 0.6363 - val_accuracy: 0.9035 - val_loss: 0.3126
# Epoch 95/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7241 - loss: 0.7044 - val_accuracy: 0.8553 - val_loss: 0.4053
# Epoch 96/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7294 - loss: 0.6702 - val_accuracy: 0.8953 - val_loss: 0.3393
# Epoch 97/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7306 - loss: 0.6540 - val_accuracy: 0.9024 - val_loss: 0.3216
# Epoch 98/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7506 - loss: 0.6126 - val_accuracy: 0.8782 - val_loss: 0.3708
# Epoch 99/600
# 213/213 - 4s - 17ms/step - accuracy: 0.7565 - loss: 0.6073 - val_accuracy: 0.8971 - val_loss: 0.3319
# Epoch 100/600
# 213/213 - 4s - 19ms/step - accuracy: 0.7359 - loss: 0.6384 - val_accuracy: 0.8771 - val_loss: 0.3982
# Epoch 101/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7424 - loss: 0.6423 - val_accuracy: 0.8976 - val_loss: 0.3696
# Epoch 102/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7429 - loss: 0.6555 - val_accuracy: 0.8753 - val_loss: 0.4088
# Epoch 103/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7347 - loss: 0.6647 - val_accuracy: 0.8465 - val_loss: 0.4370
# Epoch 104/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7476 - loss: 0.6156 - val_accuracy: 0.8876 - val_loss: 0.3477
# Epoch 105/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7418 - loss: 0.6363 - val_accuracy: 0.9076 - val_loss: 0.3117
# Epoch 106/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7524 - loss: 0.6200 - val_accuracy: 0.8982 - val_loss: 0.3131
# Epoch 107/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7541 - loss: 0.6348 - val_accuracy: 0.8724 - val_loss: 0.3530
# Epoch 108/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7429 - loss: 0.6581 - val_accuracy: 0.8918 - val_loss: 0.3281
# Epoch 109/600
# 213/213 - 4s - 18ms/step - accuracy: 0.7482 - loss: 0.6072 - val_accuracy: 0.9018 - val_loss: 0.3126
# Epoch 110/600
# 213/213 - 4s - 17ms/step - accuracy: 0.7471 - loss: 0.6520 - val_accuracy: 0.8912 - val_loss: 0.3304
# Epoch 111/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7565 - loss: 0.6254 - val_accuracy: 0.8776 - val_loss: 0.3875
# Epoch 112/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7606 - loss: 0.5774 - val_accuracy: 0.8782 - val_loss: 0.3563
# Epoch 113/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7518 - loss: 0.6185 - val_accuracy: 0.8806 - val_loss: 0.3702
# Epoch 114/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7612 - loss: 0.5999 - val_accuracy: 0.8929 - val_loss: 0.3332
# Epoch 115/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7688 - loss: 0.5968 - val_accuracy: 0.9029 - val_loss: 0.3152
# Epoch 116/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7624 - loss: 0.6330 - val_accuracy: 0.9082 - val_loss: 0.3007
# Epoch 117/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7388 - loss: 0.6433 - val_accuracy: 0.8694 - val_loss: 0.3999
# Epoch 118/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7582 - loss: 0.6120 - val_accuracy: 0.8976 - val_loss: 0.3331
# Epoch 119/600
# 213/213 - 3s - 14ms/step - accuracy: 0.7524 - loss: 0.6220 - val_accuracy: 0.8859 - val_loss: 0.3380
# Epoch 120/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7476 - loss: 0.6512 - val_accuracy: 0.9053 - val_loss: 0.3150
# Epoch 121/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7388 - loss: 0.6750 - val_accuracy: 0.8959 - val_loss: 0.3219
# Epoch 122/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7706 - loss: 0.5810 - val_accuracy: 0.8753 - val_loss: 0.3636
# Epoch 123/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7682 - loss: 0.5983 - val_accuracy: 0.9165 - val_loss: 0.2715
# Epoch 124/600
# 213/213 - 3s - 15ms/step - accuracy: 0.7518 - loss: 0.6142 - val_accuracy: 0.9059 - val_loss: 0.3053
# Epoch 125/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7653 - loss: 0.5996 - val_accuracy: 0.8988 - val_loss: 0.3146
# Epoch 126/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7547 - loss: 0.6205 - val_accuracy: 0.8594 - val_loss: 0.3899
# Epoch 127/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7606 - loss: 0.6026 - val_accuracy: 0.8629 - val_loss: 0.3838
# Epoch 128/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7312 - loss: 0.6645 - val_accuracy: 0.8782 - val_loss: 0.3573
# Epoch 129/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7271 - loss: 0.6790 - val_accuracy: 0.8959 - val_loss: 0.3272
# Epoch 130/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7371 - loss: 0.6402 - val_accuracy: 0.8941 - val_loss: 0.3327
# Epoch 131/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7629 - loss: 0.6032 - val_accuracy: 0.8741 - val_loss: 0.3570
# Epoch 132/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7500 - loss: 0.6467 - val_accuracy: 0.8671 - val_loss: 0.4070
# Epoch 133/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7547 - loss: 0.5748 - val_accuracy: 0.8871 - val_loss: 0.3037
# Epoch 134/600
# 213/213 - 3s - 14ms/step - accuracy: 0.7647 - loss: 0.5841 - val_accuracy: 0.8876 - val_loss: 0.3387
# Epoch 135/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7647 - loss: 0.5776 - val_accuracy: 0.9082 - val_loss: 0.2935
# Epoch 136/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7694 - loss: 0.5739 - val_accuracy: 0.8959 - val_loss: 0.3081
# Epoch 137/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7718 - loss: 0.5875 - val_accuracy: 0.8553 - val_loss: 0.3973
# Epoch 138/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7706 - loss: 0.5943 - val_accuracy: 0.9118 - val_loss: 0.2819
# Epoch 139/600
# 213/213 - 4s - 17ms/step - accuracy: 0.7618 - loss: 0.5975 - val_accuracy: 0.8859 - val_loss: 0.3253
# Epoch 140/600
# 213/213 - 4s - 18ms/step - accuracy: 0.7647 - loss: 0.6053 - val_accuracy: 0.8865 - val_loss: 0.3384
# Epoch 141/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7547 - loss: 0.6058 - val_accuracy: 0.8694 - val_loss: 0.3958
# Epoch 142/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7582 - loss: 0.6093 - val_accuracy: 0.9071 - val_loss: 0.2857
# Epoch 143/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7741 - loss: 0.5672 - val_accuracy: 0.8847 - val_loss: 0.3402
# Epoch 144/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7800 - loss: 0.5617 - val_accuracy: 0.9082 - val_loss: 0.2897
# Epoch 145/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7824 - loss: 0.5487 - val_accuracy: 0.8724 - val_loss: 0.3460
# Epoch 146/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7835 - loss: 0.5655 - val_accuracy: 0.9000 - val_loss: 0.3011
# Epoch 147/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7641 - loss: 0.5836 - val_accuracy: 0.9147 - val_loss: 0.2820
# Epoch 148/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7906 - loss: 0.5609 - val_accuracy: 0.9241 - val_loss: 0.2516
# Epoch 149/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7929 - loss: 0.5198 - val_accuracy: 0.9088 - val_loss: 0.2680
# Epoch 150/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7859 - loss: 0.5309 - val_accuracy: 0.9076 - val_loss: 0.2677
# Epoch 151/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7871 - loss: 0.5572 - val_accuracy: 0.8994 - val_loss: 0.3080
# Epoch 152/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7788 - loss: 0.5766 - val_accuracy: 0.9182 - val_loss: 0.2664
# Epoch 153/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7747 - loss: 0.5667 - val_accuracy: 0.8953 - val_loss: 0.3060
# Epoch 154/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7947 - loss: 0.5249 - val_accuracy: 0.9153 - val_loss: 0.2673
# Epoch 155/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7900 - loss: 0.5623 - val_accuracy: 0.9012 - val_loss: 0.2959
# Epoch 156/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7712 - loss: 0.5853 - val_accuracy: 0.9194 - val_loss: 0.2636
# Epoch 157/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7924 - loss: 0.5452 - val_accuracy: 0.9100 - val_loss: 0.2670
# Epoch 158/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7712 - loss: 0.5647 - val_accuracy: 0.9041 - val_loss: 0.2960
# Epoch 159/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7918 - loss: 0.5251 - val_accuracy: 0.9265 - val_loss: 0.2479
# Epoch 160/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7724 - loss: 0.5851 - val_accuracy: 0.8753 - val_loss: 0.3620
# Epoch 161/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7876 - loss: 0.5584 - val_accuracy: 0.9288 - val_loss: 0.2439
# Epoch 162/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8000 - loss: 0.5184 - val_accuracy: 0.9106 - val_loss: 0.2681
# Epoch 163/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7888 - loss: 0.5365 - val_accuracy: 0.9188 - val_loss: 0.2503
# Epoch 164/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7806 - loss: 0.5421 - val_accuracy: 0.9224 - val_loss: 0.2355
# Epoch 165/600
# 213/213 - 3s - 16ms/step - accuracy: 0.7882 - loss: 0.5295 - val_accuracy: 0.8841 - val_loss: 0.3193
# Epoch 166/600
# 213/213 - 4s - 20ms/step - accuracy: 0.7753 - loss: 0.5747 - val_accuracy: 0.8935 - val_loss: 0.3218
# Epoch 167/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7676 - loss: 0.5790 - val_accuracy: 0.8888 - val_loss: 0.3219
# Epoch 168/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7865 - loss: 0.5456 - val_accuracy: 0.9229 - val_loss: 0.2526
# Epoch 169/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7953 - loss: 0.5171 - val_accuracy: 0.9271 - val_loss: 0.2384
# Epoch 170/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7835 - loss: 0.5642 - val_accuracy: 0.9200 - val_loss: 0.2440
# Epoch 171/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7894 - loss: 0.5380 - val_accuracy: 0.8965 - val_loss: 0.2989
# Epoch 172/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7800 - loss: 0.5596 - val_accuracy: 0.9088 - val_loss: 0.2594
# Epoch 173/600
# 213/213 - 2s - 7ms/step - accuracy: 0.7812 - loss: 0.5455 - val_accuracy: 0.9100 - val_loss: 0.2501
# Epoch 174/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7829 - loss: 0.5411 - val_accuracy: 0.9359 - val_loss: 0.2265
# Epoch 175/600
# 213/213 - 3s - 15ms/step - accuracy: 0.7971 - loss: 0.5413 - val_accuracy: 0.9147 - val_loss: 0.2558
# Epoch 176/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7976 - loss: 0.5168 - val_accuracy: 0.9082 - val_loss: 0.2541
# Epoch 177/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8029 - loss: 0.5097 - val_accuracy: 0.9047 - val_loss: 0.2805
# Epoch 178/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7924 - loss: 0.5534 - val_accuracy: 0.9241 - val_loss: 0.2236
# Epoch 179/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7882 - loss: 0.5252 - val_accuracy: 0.9118 - val_loss: 0.2571
# Epoch 180/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7665 - loss: 0.5802 - val_accuracy: 0.9241 - val_loss: 0.2381
# Epoch 181/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7953 - loss: 0.5244 - val_accuracy: 0.9271 - val_loss: 0.2349
# Epoch 182/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7865 - loss: 0.5551 - val_accuracy: 0.9300 - val_loss: 0.2261
# Epoch 183/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7935 - loss: 0.5146 - val_accuracy: 0.9047 - val_loss: 0.2817
# Epoch 184/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7794 - loss: 0.5472 - val_accuracy: 0.9047 - val_loss: 0.2906
# Epoch 185/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8041 - loss: 0.5126 - val_accuracy: 0.9082 - val_loss: 0.2775
# Epoch 186/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7924 - loss: 0.5160 - val_accuracy: 0.9035 - val_loss: 0.3024
# Epoch 187/600
# 213/213 - 3s - 13ms/step - accuracy: 0.7894 - loss: 0.5196 - val_accuracy: 0.9247 - val_loss: 0.2317
# Epoch 188/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7971 - loss: 0.5050 - val_accuracy: 0.9276 - val_loss: 0.2318
# Epoch 189/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7918 - loss: 0.5255 - val_accuracy: 0.9129 - val_loss: 0.2556
# Epoch 190/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7871 - loss: 0.5366 - val_accuracy: 0.8971 - val_loss: 0.2962
# Epoch 191/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7682 - loss: 0.5589 - val_accuracy: 0.9053 - val_loss: 0.2852
# Epoch 192/600
# 213/213 - 3s - 16ms/step - accuracy: 0.7965 - loss: 0.5202 - val_accuracy: 0.9288 - val_loss: 0.2207
# Epoch 193/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7894 - loss: 0.5403 - val_accuracy: 0.9318 - val_loss: 0.2119
# Epoch 194/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8059 - loss: 0.4996 - val_accuracy: 0.9200 - val_loss: 0.2437
# Epoch 195/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7918 - loss: 0.5244 - val_accuracy: 0.9353 - val_loss: 0.2164
# Epoch 196/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7759 - loss: 0.6019 - val_accuracy: 0.9212 - val_loss: 0.2409
# Epoch 197/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8059 - loss: 0.5126 - val_accuracy: 0.9153 - val_loss: 0.2474
# Epoch 198/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7971 - loss: 0.5044 - val_accuracy: 0.9241 - val_loss: 0.2355
# Epoch 199/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8124 - loss: 0.4919 - val_accuracy: 0.9165 - val_loss: 0.2412
# Epoch 200/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8118 - loss: 0.4868 - val_accuracy: 0.9182 - val_loss: 0.2329
# Epoch 201/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7794 - loss: 0.5480 - val_accuracy: 0.9235 - val_loss: 0.2567
# Epoch 202/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8000 - loss: 0.5110 - val_accuracy: 0.9247 - val_loss: 0.2495
# Epoch 203/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8012 - loss: 0.5258 - val_accuracy: 0.8835 - val_loss: 0.3406
# Epoch 204/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7871 - loss: 0.5422 - val_accuracy: 0.9088 - val_loss: 0.2580
# Epoch 205/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7818 - loss: 0.5558 - val_accuracy: 0.9153 - val_loss: 0.2471
# Epoch 206/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8253 - loss: 0.4721 - val_accuracy: 0.9418 - val_loss: 0.1912
# Epoch 207/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8129 - loss: 0.5009 - val_accuracy: 0.9212 - val_loss: 0.2288
# Epoch 208/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8024 - loss: 0.5031 - val_accuracy: 0.9106 - val_loss: 0.2719
# Epoch 209/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8029 - loss: 0.5006 - val_accuracy: 0.9153 - val_loss: 0.2417
# Epoch 210/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8147 - loss: 0.4734 - val_accuracy: 0.9224 - val_loss: 0.2368
# Epoch 211/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8065 - loss: 0.4820 - val_accuracy: 0.9082 - val_loss: 0.2767
# Epoch 212/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8012 - loss: 0.5050 - val_accuracy: 0.9282 - val_loss: 0.2277
# Epoch 213/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8018 - loss: 0.5033 - val_accuracy: 0.9312 - val_loss: 0.2012
# Epoch 214/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7994 - loss: 0.5233 - val_accuracy: 0.9194 - val_loss: 0.2551
# Epoch 215/600
# 213/213 - 2s - 11ms/step - accuracy: 0.7841 - loss: 0.5373 - val_accuracy: 0.9041 - val_loss: 0.2754
# Epoch 216/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7947 - loss: 0.5225 - val_accuracy: 0.8994 - val_loss: 0.3066
# Epoch 217/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8000 - loss: 0.5117 - val_accuracy: 0.9276 - val_loss: 0.2290
# Epoch 218/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7959 - loss: 0.5348 - val_accuracy: 0.9253 - val_loss: 0.2270
# Epoch 219/600
# 213/213 - 3s - 15ms/step - accuracy: 0.7947 - loss: 0.5228 - val_accuracy: 0.9347 - val_loss: 0.2053
# Epoch 220/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8024 - loss: 0.5243 - val_accuracy: 0.9241 - val_loss: 0.2254
# Epoch 221/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8029 - loss: 0.5400 - val_accuracy: 0.9253 - val_loss: 0.2359
# Epoch 222/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8094 - loss: 0.4955 - val_accuracy: 0.8853 - val_loss: 0.3369
# Epoch 223/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7841 - loss: 0.5445 - val_accuracy: 0.9159 - val_loss: 0.2602
# Epoch 224/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8059 - loss: 0.5020 - val_accuracy: 0.9118 - val_loss: 0.2776
# Epoch 225/600
# 213/213 - 4s - 21ms/step - accuracy: 0.8088 - loss: 0.5060 - val_accuracy: 0.8847 - val_loss: 0.3245
# Epoch 226/600
# 213/213 - 2s - 8ms/step - accuracy: 0.7912 - loss: 0.5407 - val_accuracy: 0.9135 - val_loss: 0.2598
# Epoch 227/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8041 - loss: 0.4869 - val_accuracy: 0.9241 - val_loss: 0.2270
# Epoch 228/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8329 - loss: 0.4577 - val_accuracy: 0.9212 - val_loss: 0.2598
# Epoch 229/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8000 - loss: 0.5292 - val_accuracy: 0.9306 - val_loss: 0.2045
# Epoch 230/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8147 - loss: 0.5342 - val_accuracy: 0.9235 - val_loss: 0.2248
# Epoch 231/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8259 - loss: 0.4760 - val_accuracy: 0.9347 - val_loss: 0.1962
# Epoch 232/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8129 - loss: 0.4898 - val_accuracy: 0.9318 - val_loss: 0.1868
# Epoch 233/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7988 - loss: 0.5120 - val_accuracy: 0.9165 - val_loss: 0.2500
# Epoch 234/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8059 - loss: 0.4914 - val_accuracy: 0.9206 - val_loss: 0.2446
# Epoch 235/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8206 - loss: 0.4551 - val_accuracy: 0.9241 - val_loss: 0.2483
# Epoch 236/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8118 - loss: 0.4869 - val_accuracy: 0.9376 - val_loss: 0.1978
# Epoch 237/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8006 - loss: 0.5065 - val_accuracy: 0.9371 - val_loss: 0.2048
# Epoch 238/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8012 - loss: 0.5201 - val_accuracy: 0.9235 - val_loss: 0.2273
# Epoch 239/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8094 - loss: 0.4815 - val_accuracy: 0.9394 - val_loss: 0.1800
# Epoch 240/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8082 - loss: 0.4658 - val_accuracy: 0.9371 - val_loss: 0.1940
# Epoch 241/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8229 - loss: 0.4822 - val_accuracy: 0.9171 - val_loss: 0.2571
# Epoch 242/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7953 - loss: 0.5271 - val_accuracy: 0.9294 - val_loss: 0.2040
# Epoch 243/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8029 - loss: 0.4940 - val_accuracy: 0.9388 - val_loss: 0.1861
# Epoch 244/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8118 - loss: 0.4851 - val_accuracy: 0.9259 - val_loss: 0.2085
# Epoch 245/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7894 - loss: 0.5439 - val_accuracy: 0.9212 - val_loss: 0.2303
# Epoch 246/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8312 - loss: 0.4375 - val_accuracy: 0.9347 - val_loss: 0.1970
# Epoch 247/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8076 - loss: 0.4826 - val_accuracy: 0.9365 - val_loss: 0.1881
# Epoch 248/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8153 - loss: 0.4594 - val_accuracy: 0.8876 - val_loss: 0.5482
# Epoch 249/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8065 - loss: 0.5346 - val_accuracy: 0.9441 - val_loss: 0.1819
# Epoch 250/600
# 213/213 - 3s - 14ms/step - accuracy: 0.7835 - loss: 0.5945 - val_accuracy: 0.9241 - val_loss: 0.2494
# Epoch 251/600
# 213/213 - 2s - 9ms/step - accuracy: 0.7959 - loss: 0.5107 - val_accuracy: 0.9329 - val_loss: 0.2006
# Epoch 252/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8118 - loss: 0.4984 - val_accuracy: 0.9182 - val_loss: 0.2253
# Epoch 253/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8118 - loss: 0.4850 - val_accuracy: 0.9312 - val_loss: 0.2066
# Epoch 254/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8282 - loss: 0.4341 - val_accuracy: 0.9329 - val_loss: 0.1999
# Epoch 255/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8012 - loss: 0.5513 - val_accuracy: 0.9176 - val_loss: 0.2474
# Epoch 256/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8053 - loss: 0.4947 - val_accuracy: 0.9371 - val_loss: 0.1841
# Epoch 257/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8276 - loss: 0.4609 - val_accuracy: 0.9465 - val_loss: 0.1754
# Epoch 258/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7959 - loss: 0.5191 - val_accuracy: 0.9376 - val_loss: 0.1938
# Epoch 259/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8153 - loss: 0.4754 - val_accuracy: 0.9376 - val_loss: 0.1980
# Epoch 260/600
# 213/213 - 2s - 10ms/step - accuracy: 0.7941 - loss: 0.5096 - val_accuracy: 0.9206 - val_loss: 0.2321
# Epoch 261/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8200 - loss: 0.4583 - val_accuracy: 0.9412 - val_loss: 0.1725
# Epoch 262/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8276 - loss: 0.4560 - val_accuracy: 0.9388 - val_loss: 0.1782
# Epoch 263/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8212 - loss: 0.4551 - val_accuracy: 0.9353 - val_loss: 0.1974
# Epoch 264/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8082 - loss: 0.4965 - val_accuracy: 0.9324 - val_loss: 0.2059
# Epoch 265/600
# 213/213 - 4s - 18ms/step - accuracy: 0.8188 - loss: 0.4731 - val_accuracy: 0.9294 - val_loss: 0.2196
# Epoch 266/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8171 - loss: 0.4697 - val_accuracy: 0.9312 - val_loss: 0.2042
# Epoch 267/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8141 - loss: 0.4634 - val_accuracy: 0.9200 - val_loss: 0.2319
# Epoch 268/600
# 213/213 - 3s - 12ms/step - accuracy: 0.7924 - loss: 0.5267 - val_accuracy: 0.9153 - val_loss: 0.2642
# Epoch 269/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8141 - loss: 0.4806 - val_accuracy: 0.9312 - val_loss: 0.2166
# Epoch 270/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8100 - loss: 0.4734 - val_accuracy: 0.9376 - val_loss: 0.1945
# Epoch 271/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8206 - loss: 0.4837 - val_accuracy: 0.9418 - val_loss: 0.1795
# Epoch 272/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8024 - loss: 0.5047 - val_accuracy: 0.9371 - val_loss: 0.1935
# Epoch 273/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8235 - loss: 0.4595 - val_accuracy: 0.9465 - val_loss: 0.1741
# Epoch 274/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8029 - loss: 0.5013 - val_accuracy: 0.9194 - val_loss: 0.2420
# Epoch 275/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8171 - loss: 0.4655 - val_accuracy: 0.9265 - val_loss: 0.2279
# Epoch 276/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8312 - loss: 0.4405 - val_accuracy: 0.9482 - val_loss: 0.1637
# Epoch 277/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8065 - loss: 0.5076 - val_accuracy: 0.9306 - val_loss: 0.2017
# Epoch 278/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8206 - loss: 0.4735 - val_accuracy: 0.9512 - val_loss: 0.1561
# Epoch 279/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8288 - loss: 0.4550 - val_accuracy: 0.9376 - val_loss: 0.1940
# Epoch 280/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8259 - loss: 0.4531 - val_accuracy: 0.9306 - val_loss: 0.1962
# Epoch 281/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8171 - loss: 0.4802 - val_accuracy: 0.9435 - val_loss: 0.1677
# Epoch 282/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8065 - loss: 0.4907 - val_accuracy: 0.9224 - val_loss: 0.2184
# Epoch 283/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8218 - loss: 0.5009 - val_accuracy: 0.9424 - val_loss: 0.1736
# Epoch 284/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8224 - loss: 0.4726 - val_accuracy: 0.9276 - val_loss: 0.2079
# Epoch 285/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8082 - loss: 0.5059 - val_accuracy: 0.9341 - val_loss: 0.2071
# Epoch 286/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8335 - loss: 0.4306 - val_accuracy: 0.9306 - val_loss: 0.2001
# Epoch 287/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8288 - loss: 0.4617 - val_accuracy: 0.9112 - val_loss: 0.2855
# Epoch 288/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8247 - loss: 0.4672 - val_accuracy: 0.9482 - val_loss: 0.1749
# Epoch 289/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8176 - loss: 0.4907 - val_accuracy: 0.9418 - val_loss: 0.1856
# Epoch 290/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8459 - loss: 0.4067 - val_accuracy: 0.9412 - val_loss: 0.1630
# Epoch 291/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8088 - loss: 0.4866 - val_accuracy: 0.9324 - val_loss: 0.1966
# Epoch 292/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8176 - loss: 0.4550 - val_accuracy: 0.9212 - val_loss: 0.2204
# Epoch 293/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8312 - loss: 0.4250 - val_accuracy: 0.9353 - val_loss: 0.1826
# Epoch 294/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8012 - loss: 0.4966 - val_accuracy: 0.9347 - val_loss: 0.2006
# Epoch 295/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8194 - loss: 0.4555 - val_accuracy: 0.9306 - val_loss: 0.2013
# Epoch 296/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8271 - loss: 0.4605 - val_accuracy: 0.9241 - val_loss: 0.2239
# Epoch 297/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8112 - loss: 0.5070 - val_accuracy: 0.9435 - val_loss: 0.1885
# Epoch 298/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8335 - loss: 0.4302 - val_accuracy: 0.9541 - val_loss: 0.1502
# Epoch 299/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8324 - loss: 0.4347 - val_accuracy: 0.9541 - val_loss: 0.1556
# Epoch 300/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8382 - loss: 0.4225 - val_accuracy: 0.9288 - val_loss: 0.2089
# Epoch 301/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8282 - loss: 0.4605 - val_accuracy: 0.9335 - val_loss: 0.2125
# Epoch 302/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8124 - loss: 0.4850 - val_accuracy: 0.9206 - val_loss: 0.2233
# Epoch 303/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8006 - loss: 0.5184 - val_accuracy: 0.9435 - val_loss: 0.1782
# Epoch 304/600
# 213/213 - 3s - 16ms/step - accuracy: 0.8182 - loss: 0.4659 - val_accuracy: 0.9565 - val_loss: 0.1461
# Epoch 305/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8129 - loss: 0.4976 - val_accuracy: 0.9329 - val_loss: 0.2106
# Epoch 306/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8229 - loss: 0.4694 - val_accuracy: 0.9394 - val_loss: 0.1872
# Epoch 307/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8329 - loss: 0.4367 - val_accuracy: 0.9553 - val_loss: 0.1479
# Epoch 308/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8282 - loss: 0.4417 - val_accuracy: 0.9453 - val_loss: 0.1578
# Epoch 309/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8347 - loss: 0.4363 - val_accuracy: 0.9218 - val_loss: 0.2100
# Epoch 310/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8094 - loss: 0.4888 - val_accuracy: 0.9288 - val_loss: 0.1895
# Epoch 311/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8147 - loss: 0.4741 - val_accuracy: 0.9553 - val_loss: 0.1458
# Epoch 312/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8429 - loss: 0.4080 - val_accuracy: 0.9359 - val_loss: 0.1709
# Epoch 313/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8106 - loss: 0.4731 - val_accuracy: 0.9612 - val_loss: 0.1345
# Epoch 314/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8153 - loss: 0.4504 - val_accuracy: 0.9312 - val_loss: 0.2190
# Epoch 315/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8188 - loss: 0.4597 - val_accuracy: 0.9353 - val_loss: 0.1910
# Epoch 316/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8241 - loss: 0.4634 - val_accuracy: 0.9447 - val_loss: 0.1653
# Epoch 317/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8229 - loss: 0.4785 - val_accuracy: 0.9318 - val_loss: 0.2024
# Epoch 318/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8247 - loss: 0.4464 - val_accuracy: 0.9365 - val_loss: 0.1772
# Epoch 319/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8347 - loss: 0.4329 - val_accuracy: 0.9447 - val_loss: 0.1699
# Epoch 320/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8359 - loss: 0.4164 - val_accuracy: 0.9559 - val_loss: 0.1366
# Epoch 321/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8365 - loss: 0.4334 - val_accuracy: 0.9500 - val_loss: 0.1699
# Epoch 322/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8441 - loss: 0.4366 - val_accuracy: 0.9400 - val_loss: 0.1794
# Epoch 323/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8306 - loss: 0.4440 - val_accuracy: 0.9347 - val_loss: 0.1915
# Epoch 324/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8053 - loss: 0.5256 - val_accuracy: 0.9447 - val_loss: 0.1709
# Epoch 325/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8129 - loss: 0.4786 - val_accuracy: 0.9488 - val_loss: 0.1625
# Epoch 326/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8088 - loss: 0.5120 - val_accuracy: 0.9506 - val_loss: 0.1668
# Epoch 327/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8224 - loss: 0.4654 - val_accuracy: 0.9506 - val_loss: 0.1514
# Epoch 328/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8335 - loss: 0.4338 - val_accuracy: 0.9453 - val_loss: 0.1808
# Epoch 329/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8235 - loss: 0.4720 - val_accuracy: 0.9388 - val_loss: 0.1795
# Epoch 330/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8312 - loss: 0.4200 - val_accuracy: 0.9588 - val_loss: 0.1380
# Epoch 331/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8329 - loss: 0.4351 - val_accuracy: 0.9547 - val_loss: 0.1441
# Epoch 332/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8247 - loss: 0.4605 - val_accuracy: 0.9424 - val_loss: 0.1624
# Epoch 333/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8353 - loss: 0.4201 - val_accuracy: 0.9459 - val_loss: 0.1716
# Epoch 334/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8247 - loss: 0.4245 - val_accuracy: 0.9571 - val_loss: 0.1431
# Epoch 335/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8294 - loss: 0.4659 - val_accuracy: 0.9518 - val_loss: 0.1526
# Epoch 336/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8282 - loss: 0.4447 - val_accuracy: 0.9447 - val_loss: 0.1791
# Epoch 337/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8353 - loss: 0.4398 - val_accuracy: 0.9612 - val_loss: 0.1358
# Epoch 338/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8129 - loss: 0.4734 - val_accuracy: 0.9418 - val_loss: 0.1779
# Epoch 339/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8047 - loss: 0.5209 - val_accuracy: 0.9294 - val_loss: 0.2052
# Epoch 340/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8318 - loss: 0.4676 - val_accuracy: 0.9359 - val_loss: 0.2033
# Epoch 341/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8394 - loss: 0.4308 - val_accuracy: 0.9424 - val_loss: 0.1670
# Epoch 342/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8341 - loss: 0.4318 - val_accuracy: 0.9435 - val_loss: 0.1677
# Epoch 343/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8400 - loss: 0.4370 - val_accuracy: 0.9594 - val_loss: 0.1358
# Epoch 344/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8500 - loss: 0.3886 - val_accuracy: 0.9606 - val_loss: 0.1351
# Epoch 345/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8547 - loss: 0.3875 - val_accuracy: 0.9371 - val_loss: 0.1897
# Epoch 346/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8359 - loss: 0.4347 - val_accuracy: 0.9476 - val_loss: 0.1540
# Epoch 347/600
# 213/213 - 4s - 18ms/step - accuracy: 0.8371 - loss: 0.4236 - val_accuracy: 0.9606 - val_loss: 0.1377
# Epoch 348/600
# 213/213 - 4s - 18ms/step - accuracy: 0.8435 - loss: 0.4201 - val_accuracy: 0.9559 - val_loss: 0.1414
# Epoch 349/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8441 - loss: 0.4126 - val_accuracy: 0.9594 - val_loss: 0.1468
# Epoch 350/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8371 - loss: 0.4490 - val_accuracy: 0.9412 - val_loss: 0.1729
# Epoch 351/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8371 - loss: 0.4316 - val_accuracy: 0.9582 - val_loss: 0.1471
# Epoch 352/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8241 - loss: 0.4552 - val_accuracy: 0.9541 - val_loss: 0.1513
# Epoch 353/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8282 - loss: 0.4596 - val_accuracy: 0.9459 - val_loss: 0.1689
# Epoch 354/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8259 - loss: 0.4569 - val_accuracy: 0.9506 - val_loss: 0.1593
# Epoch 355/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8394 - loss: 0.4366 - val_accuracy: 0.9371 - val_loss: 0.1951
# Epoch 356/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8282 - loss: 0.4714 - val_accuracy: 0.9259 - val_loss: 0.2251
# Epoch 357/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8324 - loss: 0.4426 - val_accuracy: 0.9435 - val_loss: 0.1720
# Epoch 358/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8347 - loss: 0.4438 - val_accuracy: 0.9447 - val_loss: 0.1641
# Epoch 359/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8229 - loss: 0.4575 - val_accuracy: 0.9506 - val_loss: 0.1610
# Epoch 360/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8112 - loss: 0.4842 - val_accuracy: 0.9518 - val_loss: 0.1674
# Epoch 361/600
# 213/213 - 4s - 18ms/step - accuracy: 0.8359 - loss: 0.4303 - val_accuracy: 0.9559 - val_loss: 0.1559
# Epoch 362/600
# 213/213 - 4s - 18ms/step - accuracy: 0.8441 - loss: 0.4408 - val_accuracy: 0.9512 - val_loss: 0.1533
# Epoch 363/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8347 - loss: 0.4408 - val_accuracy: 0.9612 - val_loss: 0.1319
# Epoch 364/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8406 - loss: 0.4351 - val_accuracy: 0.9382 - val_loss: 0.1876
# Epoch 365/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8376 - loss: 0.4443 - val_accuracy: 0.9576 - val_loss: 0.1438
# Epoch 366/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8324 - loss: 0.4626 - val_accuracy: 0.9682 - val_loss: 0.1195
# Epoch 367/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8359 - loss: 0.4426 - val_accuracy: 0.9565 - val_loss: 0.1592
# Epoch 368/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8318 - loss: 0.4190 - val_accuracy: 0.9594 - val_loss: 0.1373
# Epoch 369/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8547 - loss: 0.3995 - val_accuracy: 0.9694 - val_loss: 0.1187
# Epoch 370/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8353 - loss: 0.4190 - val_accuracy: 0.9512 - val_loss: 0.1582
# Epoch 371/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8282 - loss: 0.4440 - val_accuracy: 0.9571 - val_loss: 0.1437
# Epoch 372/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8094 - loss: 0.5010 - val_accuracy: 0.9353 - val_loss: 0.2000
# Epoch 373/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8388 - loss: 0.4557 - val_accuracy: 0.9635 - val_loss: 0.1382
# Epoch 374/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8318 - loss: 0.4581 - val_accuracy: 0.9559 - val_loss: 0.1456
# Epoch 375/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8365 - loss: 0.4373 - val_accuracy: 0.9600 - val_loss: 0.1324
# Epoch 376/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8359 - loss: 0.4364 - val_accuracy: 0.9482 - val_loss: 0.1620
# Epoch 377/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8335 - loss: 0.4415 - val_accuracy: 0.9541 - val_loss: 0.1542
# Epoch 378/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8388 - loss: 0.4403 - val_accuracy: 0.9624 - val_loss: 0.1420
# Epoch 379/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8371 - loss: 0.4753 - val_accuracy: 0.9524 - val_loss: 0.1593
# Epoch 380/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8488 - loss: 0.3904 - val_accuracy: 0.9553 - val_loss: 0.1599
# Epoch 381/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8424 - loss: 0.4243 - val_accuracy: 0.9618 - val_loss: 0.1267
# Epoch 382/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8176 - loss: 0.4576 - val_accuracy: 0.9506 - val_loss: 0.1545
# Epoch 383/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8335 - loss: 0.4669 - val_accuracy: 0.9524 - val_loss: 0.1628
# Epoch 384/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8300 - loss: 0.4467 - val_accuracy: 0.9653 - val_loss: 0.1353
# Epoch 385/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8441 - loss: 0.4031 - val_accuracy: 0.9653 - val_loss: 0.1227
# Epoch 386/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8235 - loss: 0.4492 - val_accuracy: 0.9359 - val_loss: 0.2234
# Epoch 387/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8412 - loss: 0.4142 - val_accuracy: 0.9671 - val_loss: 0.1203
# Epoch 388/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8435 - loss: 0.4221 - val_accuracy: 0.9576 - val_loss: 0.1420
# Epoch 389/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8471 - loss: 0.4047 - val_accuracy: 0.9629 - val_loss: 0.1301
# Epoch 390/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8388 - loss: 0.4158 - val_accuracy: 0.9653 - val_loss: 0.1209
# Epoch 391/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8259 - loss: 0.4689 - val_accuracy: 0.9676 - val_loss: 0.1190
# Epoch 392/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8712 - loss: 0.3749 - val_accuracy: 0.9653 - val_loss: 0.1254
# Epoch 393/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8482 - loss: 0.4198 - val_accuracy: 0.9659 - val_loss: 0.1328
# Epoch 394/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8535 - loss: 0.4022 - val_accuracy: 0.9576 - val_loss: 0.1485
# Epoch 395/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8647 - loss: 0.3975 - val_accuracy: 0.9635 - val_loss: 0.1185
# Epoch 396/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8371 - loss: 0.4272 - val_accuracy: 0.9618 - val_loss: 0.1257
# Epoch 397/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8518 - loss: 0.4156 - val_accuracy: 0.9588 - val_loss: 0.1358
# Epoch 398/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8359 - loss: 0.4449 - val_accuracy: 0.9553 - val_loss: 0.1474
# Epoch 399/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8371 - loss: 0.4241 - val_accuracy: 0.9641 - val_loss: 0.1300
# Epoch 400/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8453 - loss: 0.4144 - val_accuracy: 0.9224 - val_loss: 0.2374
# Epoch 401/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8276 - loss: 0.4679 - val_accuracy: 0.9618 - val_loss: 0.1335
# Epoch 402/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8535 - loss: 0.3747 - val_accuracy: 0.9618 - val_loss: 0.1318
# Epoch 403/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8488 - loss: 0.4291 - val_accuracy: 0.9594 - val_loss: 0.1374
# Epoch 404/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8559 - loss: 0.4090 - val_accuracy: 0.9629 - val_loss: 0.1314
# Epoch 405/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8253 - loss: 0.4434 - val_accuracy: 0.9476 - val_loss: 0.1714
# Epoch 406/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8312 - loss: 0.4724 - val_accuracy: 0.9447 - val_loss: 0.1786
# Epoch 407/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8512 - loss: 0.3944 - val_accuracy: 0.9512 - val_loss: 0.1446
# Epoch 408/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8594 - loss: 0.3936 - val_accuracy: 0.9694 - val_loss: 0.1107
# Epoch 409/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8512 - loss: 0.3955 - val_accuracy: 0.9594 - val_loss: 0.1498
# Epoch 410/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8494 - loss: 0.4059 - val_accuracy: 0.9606 - val_loss: 0.1411
# Epoch 411/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8524 - loss: 0.3849 - val_accuracy: 0.9453 - val_loss: 0.1695
# Epoch 412/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8365 - loss: 0.4585 - val_accuracy: 0.9565 - val_loss: 0.1483
# Epoch 413/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8371 - loss: 0.4447 - val_accuracy: 0.9624 - val_loss: 0.1259
# Epoch 414/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8394 - loss: 0.4317 - val_accuracy: 0.9635 - val_loss: 0.1243
# Epoch 415/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8259 - loss: 0.4503 - val_accuracy: 0.9541 - val_loss: 0.1468
# Epoch 416/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8512 - loss: 0.4030 - val_accuracy: 0.9571 - val_loss: 0.1417
# Epoch 417/600
# ...
# 213/213 - 3s - 13ms/step - accuracy: 0.8412 - loss: 0.4276 - val_accuracy: 0.9724 - val_loss: 0.1106
# Epoch 470/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8418 - loss: 0.4250 - val_accuracy: 0.9641 - val_loss: 0.1235
# Epoch 471/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8553 - loss: 0.3885 - val_accuracy: 0.9676 - val_loss: 0.1316
# Epoch 472/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8482 - loss: 0.4029 - val_accuracy: 0.9635 - val_loss: 0.1307
# Epoch 473/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8524 - loss: 0.3994 - val_accuracy: 0.9676 - val_loss: 0.1231
# Epoch 474/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8559 - loss: 0.3871 - val_accuracy: 0.9753 - val_loss: 0.1063
# Epoch 475/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8524 - loss: 0.3898 - val_accuracy: 0.9688 - val_loss: 0.1156
# Epoch 476/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8588 - loss: 0.3705 - val_accuracy: 0.9571 - val_loss: 0.1483
# Epoch 477/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8635 - loss: 0.3777 - val_accuracy: 0.9724 - val_loss: 0.1040
# Epoch 478/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8547 - loss: 0.3909 - val_accuracy: 0.9706 - val_loss: 0.1148
# Epoch 479/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8682 - loss: 0.3578 - val_accuracy: 0.9706 - val_loss: 0.1201
# Epoch 480/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8618 - loss: 0.4135 - val_accuracy: 0.9653 - val_loss: 0.1223
# Epoch 481/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8641 - loss: 0.3819 - val_accuracy: 0.9682 - val_loss: 0.1138
# Epoch 482/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8847 - loss: 0.3191 - val_accuracy: 0.9653 - val_loss: 0.1111
# Epoch 483/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8424 - loss: 0.4231 - val_accuracy: 0.9718 - val_loss: 0.1120
# Epoch 484/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8529 - loss: 0.4095 - val_accuracy: 0.9624 - val_loss: 0.1248
# Epoch 485/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8282 - loss: 0.4499 - val_accuracy: 0.9571 - val_loss: 0.1488
# Epoch 486/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8271 - loss: 0.4599 - val_accuracy: 0.9376 - val_loss: 0.1836
# Epoch 487/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8447 - loss: 0.4172 - val_accuracy: 0.9565 - val_loss: 0.1514
# Epoch 488/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8571 - loss: 0.4247 - val_accuracy: 0.9747 - val_loss: 0.1109
# Epoch 489/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8524 - loss: 0.4136 - val_accuracy: 0.9553 - val_loss: 0.1335
# Epoch 490/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8424 - loss: 0.4264 - val_accuracy: 0.9524 - val_loss: 0.1392
# Epoch 491/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8629 - loss: 0.3704 - val_accuracy: 0.9618 - val_loss: 0.1306
# Epoch 492/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8600 - loss: 0.3906 - val_accuracy: 0.9582 - val_loss: 0.1456
# Epoch 493/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8682 - loss: 0.3916 - val_accuracy: 0.9747 - val_loss: 0.1028
# Epoch 494/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8653 - loss: 0.3648 - val_accuracy: 0.9700 - val_loss: 0.1101
# Epoch 495/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8559 - loss: 0.3752 - val_accuracy: 0.9647 - val_loss: 0.1197
# Epoch 496/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8576 - loss: 0.3973 - val_accuracy: 0.9694 - val_loss: 0.1132
# Epoch 497/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8471 - loss: 0.4217 - val_accuracy: 0.9629 - val_loss: 0.1176
# Epoch 498/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8818 - loss: 0.3590 - val_accuracy: 0.9706 - val_loss: 0.1053
# Epoch 499/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8576 - loss: 0.4188 - val_accuracy: 0.9476 - val_loss: 0.1750
# Epoch 500/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8371 - loss: 0.4584 - val_accuracy: 0.9671 - val_loss: 0.1190
# Epoch 501/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8459 - loss: 0.4143 - val_accuracy: 0.9676 - val_loss: 0.1192
# Epoch 502/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8647 - loss: 0.3806 - val_accuracy: 0.9706 - val_loss: 0.1270
# Epoch 503/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8518 - loss: 0.3945 - val_accuracy: 0.9641 - val_loss: 0.1221
# Epoch 504/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8506 - loss: 0.4037 - val_accuracy: 0.9653 - val_loss: 0.1150
# Epoch 505/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8471 - loss: 0.4042 - val_accuracy: 0.9729 - val_loss: 0.1087
# Epoch 506/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8612 - loss: 0.3929 - val_accuracy: 0.9712 - val_loss: 0.1141
# Epoch 507/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8647 - loss: 0.3699 - val_accuracy: 0.9724 - val_loss: 0.1099
# Epoch 508/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8641 - loss: 0.3715 - val_accuracy: 0.9724 - val_loss: 0.1063
# Epoch 509/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8624 - loss: 0.3926 - val_accuracy: 0.9547 - val_loss: 0.1465
# Epoch 510/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8606 - loss: 0.3734 - val_accuracy: 0.9735 - val_loss: 0.1030
# Epoch 511/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8582 - loss: 0.3964 - val_accuracy: 0.9712 - val_loss: 0.1043
# Epoch 512/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8500 - loss: 0.4034 - val_accuracy: 0.9776 - val_loss: 0.1110
# Epoch 513/600
# 213/213 - 3s - 16ms/step - accuracy: 0.8653 - loss: 0.3823 - val_accuracy: 0.9676 - val_loss: 0.1188
# Epoch 514/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8688 - loss: 0.3676 - val_accuracy: 0.9706 - val_loss: 0.1031
# Epoch 515/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8482 - loss: 0.4065 - val_accuracy: 0.9635 - val_loss: 0.1189
# Epoch 516/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8735 - loss: 0.3480 - val_accuracy: 0.9653 - val_loss: 0.1220
# Epoch 517/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8571 - loss: 0.3725 - val_accuracy: 0.9682 - val_loss: 0.1130
# Epoch 518/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8606 - loss: 0.4108 - val_accuracy: 0.9712 - val_loss: 0.0982
# Epoch 519/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8653 - loss: 0.3896 - val_accuracy: 0.9676 - val_loss: 0.1158
# Epoch 520/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8582 - loss: 0.4029 - val_accuracy: 0.9735 - val_loss: 0.0996
# Epoch 521/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8476 - loss: 0.4197 - val_accuracy: 0.9718 - val_loss: 0.1108
# Epoch 522/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8671 - loss: 0.3835 - val_accuracy: 0.9641 - val_loss: 0.1174
# Epoch 523/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8635 - loss: 0.3702 - val_accuracy: 0.9512 - val_loss: 0.1626
# Epoch 524/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8618 - loss: 0.3749 - val_accuracy: 0.9653 - val_loss: 0.1413
# Epoch 525/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8335 - loss: 0.4428 - val_accuracy: 0.9676 - val_loss: 0.1201
# Epoch 526/600
# 213/213 - 2s - 12ms/step - accuracy: 0.8653 - loss: 0.3867 - val_accuracy: 0.9582 - val_loss: 0.1247
# Epoch 527/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8529 - loss: 0.4033 - val_accuracy: 0.9653 - val_loss: 0.1186
# Epoch 528/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8529 - loss: 0.3987 - val_accuracy: 0.9747 - val_loss: 0.1074
# Epoch 529/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8547 - loss: 0.3887 - val_accuracy: 0.9694 - val_loss: 0.1096
# Epoch 530/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8541 - loss: 0.3970 - val_accuracy: 0.9647 - val_loss: 0.1407
# Epoch 531/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8482 - loss: 0.4061 - val_accuracy: 0.9682 - val_loss: 0.1078
# Epoch 532/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8618 - loss: 0.3855 - val_accuracy: 0.9694 - val_loss: 0.1241
# Epoch 533/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8471 - loss: 0.4209 - val_accuracy: 0.9718 - val_loss: 0.1078
# Epoch 534/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8724 - loss: 0.3513 - val_accuracy: 0.9635 - val_loss: 0.1332
# Epoch 535/600
# 213/213 - 3s - 15ms/step - accuracy: 0.8571 - loss: 0.3720 - val_accuracy: 0.9594 - val_loss: 0.1380
# Epoch 536/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8559 - loss: 0.4031 - val_accuracy: 0.9600 - val_loss: 0.1226
# Epoch 537/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8753 - loss: 0.3478 - val_accuracy: 0.9753 - val_loss: 0.0957
# Epoch 538/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8553 - loss: 0.3873 - val_accuracy: 0.9688 - val_loss: 0.1351
# Epoch 539/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8653 - loss: 0.3759 - val_accuracy: 0.9612 - val_loss: 0.1265
# Epoch 540/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8576 - loss: 0.4055 - val_accuracy: 0.9712 - val_loss: 0.1002
# Epoch 541/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8594 - loss: 0.3717 - val_accuracy: 0.9782 - val_loss: 0.0901
# Epoch 542/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8729 - loss: 0.3582 - val_accuracy: 0.9624 - val_loss: 0.1136
# Epoch 543/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8388 - loss: 0.4347 - val_accuracy: 0.9647 - val_loss: 0.1142
# Epoch 544/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8565 - loss: 0.3978 - val_accuracy: 0.9624 - val_loss: 0.1206
# Epoch 545/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8594 - loss: 0.3933 - val_accuracy: 0.9718 - val_loss: 0.1084
# Epoch 546/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8741 - loss: 0.3518 - val_accuracy: 0.9735 - val_loss: 0.0967
# Epoch 547/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8453 - loss: 0.3953 - val_accuracy: 0.9535 - val_loss: 0.1475
# Epoch 548/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8182 - loss: 0.4875 - val_accuracy: 0.9641 - val_loss: 0.1215
# Epoch 549/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8606 - loss: 0.3640 - val_accuracy: 0.9512 - val_loss: 0.1801
# Epoch 550/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8688 - loss: 0.3674 - val_accuracy: 0.9665 - val_loss: 0.1135
# Epoch 551/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8700 - loss: 0.3632 - val_accuracy: 0.9741 - val_loss: 0.1131
# Epoch 552/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8594 - loss: 0.3687 - val_accuracy: 0.9753 - val_loss: 0.1018
# Epoch 553/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8641 - loss: 0.3628 - val_accuracy: 0.9724 - val_loss: 0.1069
# Epoch 554/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8624 - loss: 0.3722 - val_accuracy: 0.9729 - val_loss: 0.1068
# Epoch 555/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8682 - loss: 0.3661 - val_accuracy: 0.9582 - val_loss: 0.1307
# Epoch 556/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8624 - loss: 0.3646 - val_accuracy: 0.9700 - val_loss: 0.1013
# Epoch 557/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8494 - loss: 0.3889 - val_accuracy: 0.9729 - val_loss: 0.1058
# Epoch 558/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8500 - loss: 0.4090 - val_accuracy: 0.9735 - val_loss: 0.1067
# Epoch 559/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8576 - loss: 0.3920 - val_accuracy: 0.9659 - val_loss: 0.1101
# Epoch 560/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8659 - loss: 0.3886 - val_accuracy: 0.9712 - val_loss: 0.1078
# Epoch 561/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8635 - loss: 0.4007 - val_accuracy: 0.9729 - val_loss: 0.1036
# Epoch 562/600
# 213/213 - 3s - 16ms/step - accuracy: 0.8553 - loss: 0.3858 - val_accuracy: 0.9706 - val_loss: 0.1123
# Epoch 563/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8618 - loss: 0.3785 - val_accuracy: 0.9694 - val_loss: 0.1255
# Epoch 564/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8635 - loss: 0.3819 - val_accuracy: 0.9718 - val_loss: 0.1073
# Epoch 565/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8500 - loss: 0.4099 - val_accuracy: 0.9682 - val_loss: 0.1174
# Epoch 566/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8465 - loss: 0.4369 - val_accuracy: 0.9641 - val_loss: 0.1205
# Epoch 567/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8500 - loss: 0.4022 - val_accuracy: 0.9688 - val_loss: 0.1623
# Epoch 568/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8671 - loss: 0.3953 - val_accuracy: 0.9741 - val_loss: 0.1048
# Epoch 569/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8694 - loss: 0.3386 - val_accuracy: 0.9618 - val_loss: 0.1187
# Epoch 570/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8600 - loss: 0.3813 - val_accuracy: 0.9647 - val_loss: 0.1220
# Epoch 571/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8535 - loss: 0.4011 - val_accuracy: 0.9641 - val_loss: 0.1221
# Epoch 572/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8724 - loss: 0.3540 - val_accuracy: 0.9712 - val_loss: 0.1044
# Epoch 573/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8565 - loss: 0.4022 - val_accuracy: 0.9700 - val_loss: 0.1349
# Epoch 574/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8471 - loss: 0.4360 - val_accuracy: 0.9576 - val_loss: 0.1261
# Epoch 575/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8388 - loss: 0.4295 - val_accuracy: 0.9653 - val_loss: 0.1194
# Epoch 576/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8512 - loss: 0.4034 - val_accuracy: 0.9635 - val_loss: 0.1308
# Epoch 577/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8600 - loss: 0.3780 - val_accuracy: 0.9771 - val_loss: 0.0932
# Epoch 578/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8588 - loss: 0.3815 - val_accuracy: 0.9588 - val_loss: 0.1245
# Epoch 579/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8412 - loss: 0.4295 - val_accuracy: 0.9700 - val_loss: 0.1056
# Epoch 580/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8647 - loss: 0.3935 - val_accuracy: 0.9765 - val_loss: 0.0947
# Epoch 581/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8518 - loss: 0.4117 - val_accuracy: 0.9612 - val_loss: 0.1285
# Epoch 582/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8582 - loss: 0.3891 - val_accuracy: 0.9718 - val_loss: 0.1062
# Epoch 583/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8465 - loss: 0.4141 - val_accuracy: 0.9688 - val_loss: 0.1258
# Epoch 584/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8565 - loss: 0.3749 - val_accuracy: 0.9706 - val_loss: 0.1085
# Epoch 585/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8618 - loss: 0.3947 - val_accuracy: 0.9771 - val_loss: 0.0912
# Epoch 586/600
# 213/213 - 1s - 7ms/step - accuracy: 0.8565 - loss: 0.3935 - val_accuracy: 0.9618 - val_loss: 0.1213
# Epoch 587/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8524 - loss: 0.3979 - val_accuracy: 0.9718 - val_loss: 0.1139
# Epoch 588/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8518 - loss: 0.4118 - val_accuracy: 0.9700 - val_loss: 0.1349
# Epoch 589/600
# 213/213 - 2s - 10ms/step - accuracy: 0.8641 - loss: 0.3875 - val_accuracy: 0.9659 - val_loss: 0.1202
# Epoch 590/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8629 - loss: 0.4015 - val_accuracy: 0.9571 - val_loss: 0.1379
# Epoch 591/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8641 - loss: 0.3618 - val_accuracy: 0.9753 - val_loss: 0.1006
# Epoch 592/600
# 213/213 - 2s - 7ms/step - accuracy: 0.8582 - loss: 0.3484 - val_accuracy: 0.9729 - val_loss: 0.0982
# Epoch 593/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8671 - loss: 0.3616 - val_accuracy: 0.9529 - val_loss: 0.1692
# Epoch 594/600
# 213/213 - 3s - 12ms/step - accuracy: 0.8618 - loss: 0.3910 - val_accuracy: 0.9706 - val_loss: 0.1151
# Epoch 595/600
# 213/213 - 3s - 14ms/step - accuracy: 0.8576 - loss: 0.3674 - val_accuracy: 0.9682 - val_loss: 0.1243
# Epoch 596/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8588 - loss: 0.3747 - val_accuracy: 0.9629 - val_loss: 0.1186
# Epoch 597/600
# 213/213 - 2s - 8ms/step - accuracy: 0.8688 - loss: 0.3643 - val_accuracy: 0.9665 - val_loss: 0.1178
# Epoch 598/600
# 213/213 - 2s - 11ms/step - accuracy: 0.8553 - loss: 0.3809 - val_accuracy: 0.9735 - val_loss: 0.1116
# Epoch 599/600
# 213/213 - 2s - 9ms/step - accuracy: 0.8588 - loss: 0.3756 - val_accuracy: 0.9706 - val_loss: 0.1142
# Epoch 600/600
# 213/213 - 3s - 13ms/step - accuracy: 0.8465 - loss: 0.4295 - val_accuracy: 0.9712 - val_loss: 0.1131
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report (6 Qubits):
#               precision    recall  f1-score   support
#
#        Happy       0.95      0.97      0.96       297
#          Sad       0.97      0.96      0.96        68
#        Angry       0.98      0.85      0.91        98
#    Surprised       0.93      1.00      0.96       144
#      Neutral       1.00      0.99      0.99       407
#    Disgusted       0.97      0.97      0.97       136
#         Fear       0.98      0.98      0.98       298
#       Sleepy       1.00      0.94      0.97        33
#     Contempt       0.97      0.98      0.97       219
#
#     accuracy                           0.97      1700
#    macro avg       0.97      0.96      0.96      1700
# weighted avg       0.97      0.97      0.97      1700
# Test Accuracy (6 Qubits): 0.9712
# === Final Accuracy Comparison ===
# 6 Qubits: Accuracy = 0.9712

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt

# Function to create and display detailed quantum circuits
def show_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    # Random parameters for encoding & random layers
    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)  # Sample classical input for encoding

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding using RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Apply random entangling layers
        RandomLayers(rand_params, wires=range(n_qubits))

        # Measurement
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw circuit
    fig, ax = qml.draw_mpl(circuit)(sample_inputs)
    plt.title(f"Quantum Circuit with {n_qubits} Qubits & {n_layers} Random Layers")
    plt.show()

# Show circuits for 4, 6, 8, 10, 12 qubits
for q in [4, 6, 8, 10, 12]:
    show_detailed_circuit(n_qubits=q, n_layers=2)
