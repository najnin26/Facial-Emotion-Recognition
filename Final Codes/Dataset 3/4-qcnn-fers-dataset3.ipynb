# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

DATA_DIR='/kaggle/input/8-facial-expressions-for-yolo/9 Facial Expressions you need'
train = os.listdir(os.path.join(DATA_DIR,'train'))
test = os.listdir(os.path.join(DATA_DIR,'test'))
val=os.listdir(os.path.join(DATA_DIR,'valid'))
print(f'Train - {train}')
print(f'Test - {test}')
print(f'Val - {val}')
# Out:
# Train - ['labels', 'images']
# Test - ['labels', 'images']
# Val - ['labels', 'images']

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical

IMG_SIZE = 48
EMOTIONS = ['Happy', 'Sad', 'Angry', 'Surprised', 'Neutral', 'Disgusted', 'Fear', 'Sleepy', 'Contempt']  # update based on your labels
emotion_to_idx = {e: i for i, e in enumerate(EMOTIONS)}
idx_to_emotion = {i: e for i, e in enumerate(EMOTIONS)} # Add mapping from index to emotion

def load_data(folder_path):
    image_dir = os.path.join(folder_path, 'images')
    label_dir = os.path.join(folder_path, 'labels')

    images = []
    labels = []

    # Get list of label files
    label_files = sorted([f for f in os.listdir(label_dir) if f.endswith('.txt')])

    for label_fname in label_files:
        image_fname = label_fname.replace('.txt', '.jpg')
        image_path = os.path.join(image_dir, image_fname)
        label_path = os.path.join(label_dir, label_fname)

        # Check if the corresponding image file exists
        if not os.path.exists(image_path):
            print(f"Warning: Image file not found for label file {label_path}. Skipping.")
            continue

        # Load image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Warning: Could not read image file {image_path}. Skipping.")
            continue
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))  # Resize to 48×48
        images.append(img)

        # Load and parse label from YOLO format
        with open(label_path, 'r') as f:
            label_content = f.read().strip()
            # Assuming the first number in the line is the class ID
            try:
                class_id = int(label_content.split()[0])
                labels.append(class_id)
            except (ValueError, IndexError):
                print(f"Warning: Could not parse label from file {label_path}. Content: '{label_content}'. Skipping.")
                images.pop() # Remove the image if label parsing fails
                continue


    images = np.array(images)
    labels = np.array(labels)
    return images, labels
     

# Load full data from train folder
images, labels = load_data(os.path.join(DATA_DIR, 'test'))

# Normalize pixel values to be between 0 and 1
images = images / 255.0

# Reduce dataset size
n_train = 5000
n_test = 3000

train_images = images[:n_train]
train_labels = labels[:n_train]
test_images = images[-n_test:]
test_labels = labels[-n_test:]

# Add grayscale channel dimension: (N, 48, 48, 1)
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# One-hot encode the labels
train_labels_categorical = to_categorical(train_labels, num_classes=len(EMOTIONS))
test_labels_categorical = to_categorical(test_labels, num_classes=len(EMOTIONS))

# Final checks
print(f"Train images shape: {train_images.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Train labels shape: {train_labels_categorical.shape}")
print(f"Test labels shape: {test_labels_categorical.shape}")
# Out:
# 2025-07-29 13:41:11.230209: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753796471.568766      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753796471.660041      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Train images shape: (1700, 48, 48, 1)
# Test images shape: (1700, 48, 48, 1)
# Train labels shape: (1700, 9)
# Test labels shape: (1700, 9)

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.42.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.42 (from pennylane)
#   Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (25.0)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.42->pennylane)
#   Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2.4.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.6.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pennylane) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pennylane) (2024.2.0)
# Downloading pennylane-0.42.1-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 59.0 MB/s eta 0:00:00:00:010:01
# Downloading autoray-0.7.2-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 33.9 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 60.9 MB/s eta 0:00:00:00:01
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 57.3 MB/s eta 0:00:00:00:01
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 8.1 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 88.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: appdirs, scipy-openblas32, autoray, diastatic-malt, rustworkx, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.2 diastatic-malt-2.15.2 pennylane-0.42.1 pennylane-lightning-0.42.0 rustworkx-0.16.0 scipy-openblas32-0.3.30.0.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Fix random seeds
np.random.seed(0)
tf.random.set_seed(0)

# Number of classes (for this dataset)
num_classes = len(EMOTIONS)

# Define qubit patch sizes
qubit_patch_shapes = {
    4: (2, 2),
    6: (3, 2),
    8: (4, 2),
    10: (5, 2),
    12: (4, 3),
}

# ------------------ Quantum Circuit Creation -------------------
def create_circuit(n_qubits, n_layers=1):
    dev = qml.device("default.qubit", wires=n_qubits)
    rand_params = np.random.uniform(high=2*np.pi, size=(n_layers, n_qubits))

    @qml.qnode(dev)
    def circuit(phi):
        # Encode classical data into qubits
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)
        RandomLayers(rand_params, wires=range(n_qubits))
        return [qml.expval(qml.PauliZ(j)) for j in range(n_qubits)]

    return circuit

# ------------------ Quantum Convolution -------------------
def quanv(image, circuit, patch_h, patch_w):
    out_h = (image.shape[0] - patch_h) // 2 + 1
    out_w = (image.shape[1] - patch_w) // 2 + 1
    n_qubits = patch_h * patch_w
    out = np.zeros((out_h, out_w, n_qubits))
    for j in range(0, image.shape[0] - patch_h + 1, 2):
        for k in range(0, image.shape[1] - patch_w + 1, 2):
            patch = image[j:j+patch_h, k:k+patch_w, 0].flatten()
            q_results = circuit(patch)
            out[j//2, k//2, :] = q_results
    return out

# ------------------ Classical Model -------------------
def build_model(input_shape, num_classes):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ------------------ Run for Multiple Qubits -------------------
results = {}
n_qubits=4 # Changed from list [6] to integer 6

print(f"\n=== Running for {n_qubits} Qubits ===")
patch_h, patch_w = qubit_patch_shapes[n_qubits]
circuit = create_circuit(n_qubits)

# Show quantum circuit diagram
print(f"\nQuantum Circuit for {n_qubits} Qubits:")
fig, ax = qml.draw_mpl(circuit)(np.random.rand(n_qubits))
plt.show()

# Quantum preprocessing
print("Quantum preprocessing (train)...")
q_train_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in train_images])
print("Quantum preprocessing (test)...")
q_test_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in test_images])
# Out:
# === Running for 4 Qubits ===
#
# Quantum Circuit for 4 Qubits:
# Quantum preprocessing (train)...
# Quantum preprocessing (test)...

# %%
# Train classical model
model = build_model(q_train_images.shape[1:], num_classes)
model.fit(q_train_images, train_labels, validation_data=(q_test_images, test_labels),
              epochs=250, batch_size=8, verbose=2)

# Predictions & evaluation
y_pred = np.argmax(model.predict(q_test_images), axis=1)

print(f"\nClassification Report ({n_qubits} Qubits):")
print(classification_report(test_labels, y_pred, target_names=EMOTIONS))

    # Confusion Matrix
cm = confusion_matrix(test_labels, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=EMOTIONS, yticklabels=EMOTIONS)
plt.title(f"Confusion Matrix - {n_qubits} Qubits")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Accuracy
acc = model.evaluate(q_test_images, test_labels, verbose=0)[1]
print(f"Test Accuracy ({n_qubits} Qubits): {acc:.4f}")
results[n_qubits] = acc

# ------------------ Accuracy Comparison Plot -------------------
plt.figure(figsize=(8, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Quantum CNN Accuracy vs Number of Qubits (9-class Dataset)")
plt.xlabel("Number of Qubits")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

print("\n=== Final Accuracy Comparison ===")
for q, a in results.items():
    print(f"{q} Qubits: Accuracy = {a:.4f}")
# Out:
# Epoch 1/250
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 213/213 - 3s - 12ms/step - accuracy: 0.2282 - loss: 2.1354 - val_accuracy: 0.3065 - val_loss: 1.8611
# Epoch 2/250
# 213/213 - 1s - 5ms/step - accuracy: 0.2771 - loss: 1.9098 - val_accuracy: 0.3612 - val_loss: 1.7608
# Epoch 3/250
# 213/213 - 1s - 6ms/step - accuracy: 0.3194 - loss: 1.8031 - val_accuracy: 0.4176 - val_loss: 1.6409
# Epoch 4/250
# 213/213 - 1s - 6ms/step - accuracy: 0.3606 - loss: 1.7034 - val_accuracy: 0.4471 - val_loss: 1.5498
# Epoch 5/250
# 213/213 - 1s - 6ms/step - accuracy: 0.3982 - loss: 1.6320 - val_accuracy: 0.4894 - val_loss: 1.4743
# Epoch 6/250
# 213/213 - 1s - 6ms/step - accuracy: 0.4212 - loss: 1.5564 - val_accuracy: 0.5447 - val_loss: 1.3742
# Epoch 7/250
# 213/213 - 1s - 6ms/step - accuracy: 0.4406 - loss: 1.4947 - val_accuracy: 0.5824 - val_loss: 1.2930
# Epoch 8/250
# 213/213 - 1s - 6ms/step - accuracy: 0.4665 - loss: 1.4355 - val_accuracy: 0.6112 - val_loss: 1.2834
# Epoch 9/250
# 213/213 - 1s - 6ms/step - accuracy: 0.4900 - loss: 1.3509 - val_accuracy: 0.6224 - val_loss: 1.1894
# Epoch 10/250
# 213/213 - 1s - 6ms/step - accuracy: 0.5212 - loss: 1.2904 - val_accuracy: 0.6382 - val_loss: 1.1599
# Epoch 11/250
# 213/213 - 1s - 6ms/step - accuracy: 0.5571 - loss: 1.2135 - val_accuracy: 0.6594 - val_loss: 1.0961
# Epoch 12/250
# 213/213 - 1s - 6ms/step - accuracy: 0.5388 - loss: 1.1936 - val_accuracy: 0.6865 - val_loss: 0.9966
# Epoch 13/250
# 213/213 - 1s - 6ms/step - accuracy: 0.5859 - loss: 1.1304 - val_accuracy: 0.7094 - val_loss: 0.9295
# Epoch 14/250
# 213/213 - 1s - 6ms/step - accuracy: 0.5812 - loss: 1.1067 - val_accuracy: 0.7206 - val_loss: 0.9137
# Epoch 15/250
# 213/213 - 1s - 6ms/step - accuracy: 0.5959 - loss: 1.0558 - val_accuracy: 0.7294 - val_loss: 0.8670
# Epoch 16/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6276 - loss: 1.0007 - val_accuracy: 0.7382 - val_loss: 0.7971
# Epoch 17/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6212 - loss: 0.9607 - val_accuracy: 0.7735 - val_loss: 0.7500
# Epoch 18/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6582 - loss: 0.9118 - val_accuracy: 0.8024 - val_loss: 0.6623
# Epoch 19/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6759 - loss: 0.8693 - val_accuracy: 0.8018 - val_loss: 0.6961
# Epoch 20/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6953 - loss: 0.8351 - val_accuracy: 0.8347 - val_loss: 0.6052
# Epoch 21/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6841 - loss: 0.8214 - val_accuracy: 0.8318 - val_loss: 0.5762
# Epoch 22/250
# 213/213 - 1s - 6ms/step - accuracy: 0.6859 - loss: 0.8154 - val_accuracy: 0.8194 - val_loss: 0.5714
# Epoch 23/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7147 - loss: 0.7741 - val_accuracy: 0.8553 - val_loss: 0.4992
# Epoch 24/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7012 - loss: 0.7601 - val_accuracy: 0.8553 - val_loss: 0.5087
# Epoch 25/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7318 - loss: 0.7190 - val_accuracy: 0.8406 - val_loss: 0.5276
# Epoch 26/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7382 - loss: 0.6878 - val_accuracy: 0.8547 - val_loss: 0.4701
# Epoch 27/250
# 213/213 - 1s - 5ms/step - accuracy: 0.7341 - loss: 0.6731 - val_accuracy: 0.8753 - val_loss: 0.4510
# Epoch 28/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7453 - loss: 0.6790 - val_accuracy: 0.8929 - val_loss: 0.3843
# Epoch 29/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7571 - loss: 0.6183 - val_accuracy: 0.8753 - val_loss: 0.4186
# Epoch 30/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7665 - loss: 0.6037 - val_accuracy: 0.8894 - val_loss: 0.3665
# Epoch 31/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7659 - loss: 0.6076 - val_accuracy: 0.8729 - val_loss: 0.3972
# Epoch 32/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7747 - loss: 0.6033 - val_accuracy: 0.8753 - val_loss: 0.4061
# Epoch 33/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7918 - loss: 0.5484 - val_accuracy: 0.8853 - val_loss: 0.3609
# Epoch 34/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7788 - loss: 0.5764 - val_accuracy: 0.9000 - val_loss: 0.3307
# Epoch 35/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7882 - loss: 0.5577 - val_accuracy: 0.9035 - val_loss: 0.3422
# Epoch 36/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7988 - loss: 0.5419 - val_accuracy: 0.9029 - val_loss: 0.3072
# Epoch 37/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7882 - loss: 0.5672 - val_accuracy: 0.8582 - val_loss: 0.4087
# Epoch 38/250
# 213/213 - 1s - 6ms/step - accuracy: 0.7794 - loss: 0.5641 - val_accuracy: 0.8894 - val_loss: 0.3468
# Epoch 39/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8100 - loss: 0.5109 - val_accuracy: 0.9182 - val_loss: 0.2867
# Epoch 40/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8147 - loss: 0.4758 - val_accuracy: 0.9153 - val_loss: 0.2641
# Epoch 41/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8088 - loss: 0.4888 - val_accuracy: 0.9200 - val_loss: 0.2553
# Epoch 42/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8024 - loss: 0.5077 - val_accuracy: 0.9076 - val_loss: 0.2871
# Epoch 43/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8094 - loss: 0.4802 - val_accuracy: 0.8829 - val_loss: 0.3666
# Epoch 44/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8218 - loss: 0.4649 - val_accuracy: 0.8971 - val_loss: 0.3147
# Epoch 45/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8300 - loss: 0.4680 - val_accuracy: 0.8988 - val_loss: 0.3406
# Epoch 46/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8182 - loss: 0.4596 - val_accuracy: 0.9288 - val_loss: 0.2323
# Epoch 47/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8124 - loss: 0.4785 - val_accuracy: 0.8971 - val_loss: 0.3000
# Epoch 48/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8124 - loss: 0.4704 - val_accuracy: 0.9112 - val_loss: 0.2905
# Epoch 49/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8118 - loss: 0.4773 - val_accuracy: 0.9206 - val_loss: 0.2599
# Epoch 50/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8029 - loss: 0.4996 - val_accuracy: 0.8653 - val_loss: 0.3854
# Epoch 51/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8353 - loss: 0.4431 - val_accuracy: 0.9359 - val_loss: 0.2024
# Epoch 52/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8218 - loss: 0.4505 - val_accuracy: 0.9329 - val_loss: 0.2074
# Epoch 53/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8324 - loss: 0.4244 - val_accuracy: 0.9218 - val_loss: 0.2266
# Epoch 54/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8382 - loss: 0.4282 - val_accuracy: 0.9271 - val_loss: 0.2405
# Epoch 55/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8476 - loss: 0.4007 - val_accuracy: 0.9265 - val_loss: 0.2126
# Epoch 56/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8335 - loss: 0.4315 - val_accuracy: 0.9318 - val_loss: 0.2133
# Epoch 57/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8335 - loss: 0.4324 - val_accuracy: 0.9294 - val_loss: 0.2093
# Epoch 58/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8324 - loss: 0.4249 - val_accuracy: 0.9300 - val_loss: 0.2051
# Epoch 59/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8482 - loss: 0.3994 - val_accuracy: 0.9259 - val_loss: 0.2435
# Epoch 60/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8406 - loss: 0.4069 - val_accuracy: 0.9476 - val_loss: 0.1668
# Epoch 61/250
# 213/213 - 1s - 5ms/step - accuracy: 0.8665 - loss: 0.3600 - val_accuracy: 0.9282 - val_loss: 0.2158
# Epoch 62/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8529 - loss: 0.4095 - val_accuracy: 0.9253 - val_loss: 0.2482
# Epoch 63/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8529 - loss: 0.3832 - val_accuracy: 0.9376 - val_loss: 0.2057
# Epoch 64/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8441 - loss: 0.4189 - val_accuracy: 0.9271 - val_loss: 0.2281
# Epoch 65/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8547 - loss: 0.3833 - val_accuracy: 0.9482 - val_loss: 0.1648
# Epoch 66/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8647 - loss: 0.3572 - val_accuracy: 0.9506 - val_loss: 0.1708
# Epoch 67/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8588 - loss: 0.3711 - val_accuracy: 0.9306 - val_loss: 0.2046
# Epoch 68/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8606 - loss: 0.3576 - val_accuracy: 0.9447 - val_loss: 0.1670
# Epoch 69/250
# 213/213 - 1s - 5ms/step - accuracy: 0.8471 - loss: 0.3930 - val_accuracy: 0.9388 - val_loss: 0.1765
# Epoch 70/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8535 - loss: 0.3714 - val_accuracy: 0.9576 - val_loss: 0.1391
# Epoch 71/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8565 - loss: 0.3840 - val_accuracy: 0.9671 - val_loss: 0.1266
# Epoch 72/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8541 - loss: 0.3738 - val_accuracy: 0.9488 - val_loss: 0.1567
# Epoch 73/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8600 - loss: 0.3787 - val_accuracy: 0.9271 - val_loss: 0.2245
# Epoch 74/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8612 - loss: 0.3662 - val_accuracy: 0.9635 - val_loss: 0.1131
# Epoch 75/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8653 - loss: 0.3512 - val_accuracy: 0.9506 - val_loss: 0.1429
# Epoch 76/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8524 - loss: 0.3902 - val_accuracy: 0.9482 - val_loss: 0.1565
# Epoch 77/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8694 - loss: 0.3343 - val_accuracy: 0.9306 - val_loss: 0.1880
# Epoch 78/250
# 213/213 - 1s - 5ms/step - accuracy: 0.8682 - loss: 0.3494 - val_accuracy: 0.9559 - val_loss: 0.1288
# Epoch 79/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8676 - loss: 0.3512 - val_accuracy: 0.9553 - val_loss: 0.1440
# Epoch 80/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8582 - loss: 0.3724 - val_accuracy: 0.9500 - val_loss: 0.1629
# Epoch 81/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8524 - loss: 0.3644 - val_accuracy: 0.9494 - val_loss: 0.1620
# Epoch 82/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8653 - loss: 0.3456 - val_accuracy: 0.9518 - val_loss: 0.1250
# Epoch 83/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8835 - loss: 0.3110 - val_accuracy: 0.9606 - val_loss: 0.1257
# Epoch 84/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8759 - loss: 0.3107 - val_accuracy: 0.9506 - val_loss: 0.1358
# Epoch 85/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8676 - loss: 0.3399 - val_accuracy: 0.9688 - val_loss: 0.0967
# Epoch 86/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8800 - loss: 0.3254 - val_accuracy: 0.9547 - val_loss: 0.1298
# Epoch 87/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8747 - loss: 0.3203 - val_accuracy: 0.9600 - val_loss: 0.1330
# Epoch 88/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8788 - loss: 0.3232 - val_accuracy: 0.9665 - val_loss: 0.1126
# Epoch 89/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8794 - loss: 0.3153 - val_accuracy: 0.9500 - val_loss: 0.1547
# Epoch 90/250
# 213/213 - 1s - 5ms/step - accuracy: 0.8812 - loss: 0.3141 - val_accuracy: 0.9400 - val_loss: 0.1859
# Epoch 91/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8706 - loss: 0.3287 - val_accuracy: 0.9541 - val_loss: 0.1384
# Epoch 92/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8635 - loss: 0.3494 - val_accuracy: 0.9429 - val_loss: 0.1668
# Epoch 93/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8594 - loss: 0.3653 - val_accuracy: 0.9676 - val_loss: 0.1186
# Epoch 94/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8588 - loss: 0.3642 - val_accuracy: 0.9659 - val_loss: 0.1144
# Epoch 95/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8565 - loss: 0.3513 - val_accuracy: 0.9659 - val_loss: 0.1229
# Epoch 96/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8494 - loss: 0.3690 - val_accuracy: 0.9618 - val_loss: 0.1193
# Epoch 97/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8994 - loss: 0.2635 - val_accuracy: 0.9582 - val_loss: 0.1209
# Epoch 98/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8718 - loss: 0.3289 - val_accuracy: 0.9553 - val_loss: 0.1218
# Epoch 99/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8659 - loss: 0.3386 - val_accuracy: 0.9500 - val_loss: 0.1477
# Epoch 100/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8771 - loss: 0.3270 - val_accuracy: 0.9676 - val_loss: 0.1196
# Epoch 101/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8847 - loss: 0.3017 - val_accuracy: 0.9747 - val_loss: 0.0932
# Epoch 102/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8835 - loss: 0.3134 - val_accuracy: 0.9641 - val_loss: 0.1030
# Epoch 103/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8935 - loss: 0.2850 - val_accuracy: 0.9712 - val_loss: 0.0920
# Epoch 104/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8929 - loss: 0.2683 - val_accuracy: 0.9600 - val_loss: 0.1101
# Epoch 105/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8818 - loss: 0.3125 - val_accuracy: 0.9624 - val_loss: 0.1244
# Epoch 106/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8918 - loss: 0.2936 - val_accuracy: 0.9429 - val_loss: 0.1765
# Epoch 107/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8888 - loss: 0.3086 - val_accuracy: 0.9806 - val_loss: 0.0788
# Epoch 108/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9035 - loss: 0.2699 - val_accuracy: 0.9700 - val_loss: 0.0872
# Epoch 109/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8929 - loss: 0.2756 - val_accuracy: 0.9547 - val_loss: 0.1306
# Epoch 110/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8894 - loss: 0.2733 - val_accuracy: 0.9771 - val_loss: 0.0709
# Epoch 111/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8882 - loss: 0.2786 - val_accuracy: 0.9712 - val_loss: 0.1004
# Epoch 112/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8906 - loss: 0.2633 - val_accuracy: 0.9788 - val_loss: 0.0815
# Epoch 113/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8894 - loss: 0.2863 - val_accuracy: 0.9459 - val_loss: 0.1743
# Epoch 114/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8829 - loss: 0.3070 - val_accuracy: 0.9582 - val_loss: 0.1125
# Epoch 115/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9076 - loss: 0.2477 - val_accuracy: 0.9776 - val_loss: 0.0697
# Epoch 116/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9071 - loss: 0.2513 - val_accuracy: 0.9724 - val_loss: 0.1008
# Epoch 117/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8765 - loss: 0.3172 - val_accuracy: 0.9712 - val_loss: 0.1000
# Epoch 118/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9065 - loss: 0.2723 - val_accuracy: 0.9741 - val_loss: 0.0806
# Epoch 119/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8959 - loss: 0.2811 - val_accuracy: 0.9835 - val_loss: 0.0629
# Epoch 120/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8871 - loss: 0.2943 - val_accuracy: 0.9771 - val_loss: 0.0884
# Epoch 121/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8841 - loss: 0.2929 - val_accuracy: 0.9759 - val_loss: 0.0766
# Epoch 122/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8847 - loss: 0.2962 - val_accuracy: 0.9753 - val_loss: 0.0858
# Epoch 123/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8982 - loss: 0.2708 - val_accuracy: 0.9829 - val_loss: 0.0630
# Epoch 124/250
# 213/213 - 1s - 5ms/step - accuracy: 0.8994 - loss: 0.2683 - val_accuracy: 0.9806 - val_loss: 0.0667
# Epoch 125/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8924 - loss: 0.2930 - val_accuracy: 0.9700 - val_loss: 0.0931
# Epoch 126/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8918 - loss: 0.2804 - val_accuracy: 0.9671 - val_loss: 0.1093
# Epoch 127/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8806 - loss: 0.3019 - val_accuracy: 0.9712 - val_loss: 0.0776
# Epoch 128/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9024 - loss: 0.2631 - val_accuracy: 0.9871 - val_loss: 0.0646
# Epoch 129/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9112 - loss: 0.2377 - val_accuracy: 0.9682 - val_loss: 0.1009
# Epoch 130/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9053 - loss: 0.2759 - val_accuracy: 0.9765 - val_loss: 0.0880
# Epoch 131/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8947 - loss: 0.3043 - val_accuracy: 0.9694 - val_loss: 0.0953
# Epoch 132/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8865 - loss: 0.2880 - val_accuracy: 0.9635 - val_loss: 0.1301
# Epoch 133/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8941 - loss: 0.2876 - val_accuracy: 0.9771 - val_loss: 0.0789
# Epoch 134/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9053 - loss: 0.2379 - val_accuracy: 0.9700 - val_loss: 0.0908
# Epoch 135/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8924 - loss: 0.2753 - val_accuracy: 0.9741 - val_loss: 0.0814
# Epoch 136/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8912 - loss: 0.2951 - val_accuracy: 0.9688 - val_loss: 0.0895
# Epoch 137/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9206 - loss: 0.2258 - val_accuracy: 0.9688 - val_loss: 0.1129
# Epoch 138/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9024 - loss: 0.2634 - val_accuracy: 0.9776 - val_loss: 0.0772
# Epoch 139/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9000 - loss: 0.2525 - val_accuracy: 0.9729 - val_loss: 0.0824
# Epoch 140/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9065 - loss: 0.2327 - val_accuracy: 0.9853 - val_loss: 0.0572
# Epoch 141/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9112 - loss: 0.2350 - val_accuracy: 0.9812 - val_loss: 0.0632
# Epoch 142/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9035 - loss: 0.2652 - val_accuracy: 0.9829 - val_loss: 0.0644
# Epoch 143/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9100 - loss: 0.2387 - val_accuracy: 0.9741 - val_loss: 0.0902
# Epoch 144/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9000 - loss: 0.2621 - val_accuracy: 0.9788 - val_loss: 0.0725
# Epoch 145/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9012 - loss: 0.2580 - val_accuracy: 0.9718 - val_loss: 0.0855
# Epoch 146/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8882 - loss: 0.2700 - val_accuracy: 0.9812 - val_loss: 0.0600
# Epoch 147/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8953 - loss: 0.2817 - val_accuracy: 0.9824 - val_loss: 0.0675
# Epoch 148/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8941 - loss: 0.2839 - val_accuracy: 0.9765 - val_loss: 0.0660
# Epoch 149/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8900 - loss: 0.3060 - val_accuracy: 0.9794 - val_loss: 0.0850
# Epoch 150/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9071 - loss: 0.2462 - val_accuracy: 0.9806 - val_loss: 0.0565
# Epoch 151/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9029 - loss: 0.2387 - val_accuracy: 0.9847 - val_loss: 0.0560
# Epoch 152/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8988 - loss: 0.2709 - val_accuracy: 0.9835 - val_loss: 0.0582
# Epoch 153/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8988 - loss: 0.2568 - val_accuracy: 0.9876 - val_loss: 0.0482
# Epoch 154/250
# 213/213 - 1s - 5ms/step - accuracy: 0.8947 - loss: 0.2700 - val_accuracy: 0.9694 - val_loss: 0.1086
# Epoch 155/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9000 - loss: 0.2590 - val_accuracy: 0.9782 - val_loss: 0.0745
# Epoch 156/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8988 - loss: 0.2533 - val_accuracy: 0.9847 - val_loss: 0.0584
# Epoch 157/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9182 - loss: 0.2044 - val_accuracy: 0.9918 - val_loss: 0.0452
# Epoch 158/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9135 - loss: 0.2237 - val_accuracy: 0.9759 - val_loss: 0.0904
# Epoch 159/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9041 - loss: 0.2484 - val_accuracy: 0.9882 - val_loss: 0.0450
# Epoch 160/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9012 - loss: 0.2629 - val_accuracy: 0.9847 - val_loss: 0.0519
# Epoch 161/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9018 - loss: 0.2491 - val_accuracy: 0.9800 - val_loss: 0.0614
# Epoch 162/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9053 - loss: 0.2473 - val_accuracy: 0.9800 - val_loss: 0.0646
# Epoch 163/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9024 - loss: 0.2509 - val_accuracy: 0.9671 - val_loss: 0.0968
# Epoch 164/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9235 - loss: 0.2072 - val_accuracy: 0.9853 - val_loss: 0.0441
# Epoch 165/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8947 - loss: 0.2606 - val_accuracy: 0.9812 - val_loss: 0.0749
# Epoch 166/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8924 - loss: 0.2643 - val_accuracy: 0.9771 - val_loss: 0.0621
# Epoch 167/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9147 - loss: 0.2305 - val_accuracy: 0.9776 - val_loss: 0.0719
# Epoch 168/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9029 - loss: 0.2522 - val_accuracy: 0.9847 - val_loss: 0.0525
# Epoch 169/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9253 - loss: 0.2041 - val_accuracy: 0.9824 - val_loss: 0.0591
# Epoch 170/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9094 - loss: 0.2408 - val_accuracy: 0.9853 - val_loss: 0.0694
# Epoch 171/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9018 - loss: 0.2741 - val_accuracy: 0.9812 - val_loss: 0.0624
# Epoch 172/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9059 - loss: 0.2375 - val_accuracy: 0.9747 - val_loss: 0.0716
# Epoch 173/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8982 - loss: 0.2705 - val_accuracy: 0.9818 - val_loss: 0.0594
# Epoch 174/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9100 - loss: 0.2431 - val_accuracy: 0.9894 - val_loss: 0.0426
# Epoch 175/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9182 - loss: 0.2055 - val_accuracy: 0.9871 - val_loss: 0.0419
# Epoch 176/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9224 - loss: 0.1928 - val_accuracy: 0.9829 - val_loss: 0.0615
# Epoch 177/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9118 - loss: 0.2181 - val_accuracy: 0.9941 - val_loss: 0.0405
# Epoch 178/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9135 - loss: 0.2072 - val_accuracy: 0.9865 - val_loss: 0.0495
# Epoch 179/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8994 - loss: 0.2773 - val_accuracy: 0.9788 - val_loss: 0.0654
# Epoch 180/250
# 213/213 - 1s - 6ms/step - accuracy: 0.8935 - loss: 0.2698 - val_accuracy: 0.9835 - val_loss: 0.0573
# Epoch 181/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9100 - loss: 0.2273 - val_accuracy: 0.9888 - val_loss: 0.0450
# Epoch 182/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9218 - loss: 0.1988 - val_accuracy: 0.9824 - val_loss: 0.0447
# Epoch 183/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9076 - loss: 0.2287 - val_accuracy: 0.9888 - val_loss: 0.0513
# Epoch 184/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9059 - loss: 0.2348 - val_accuracy: 0.9859 - val_loss: 0.0421
# Epoch 185/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9071 - loss: 0.2465 - val_accuracy: 0.9818 - val_loss: 0.0505
# Epoch 186/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9294 - loss: 0.1774 - val_accuracy: 0.9888 - val_loss: 0.0464
# Epoch 187/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9118 - loss: 0.2268 - val_accuracy: 0.9894 - val_loss: 0.0450
# Epoch 188/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9106 - loss: 0.2647 - val_accuracy: 0.9888 - val_loss: 0.0503
# Epoch 189/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9206 - loss: 0.2150 - val_accuracy: 0.9782 - val_loss: 0.0633
# Epoch 190/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9018 - loss: 0.2659 - val_accuracy: 0.9765 - val_loss: 0.0718
# Epoch 191/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9106 - loss: 0.2170 - val_accuracy: 0.9882 - val_loss: 0.0447
# Epoch 192/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9247 - loss: 0.2025 - val_accuracy: 0.9876 - val_loss: 0.0405
# Epoch 193/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9253 - loss: 0.1953 - val_accuracy: 0.9935 - val_loss: 0.0306
# Epoch 194/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9224 - loss: 0.1950 - val_accuracy: 0.9924 - val_loss: 0.0353
# Epoch 195/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9182 - loss: 0.2096 - val_accuracy: 0.9865 - val_loss: 0.0434
# Epoch 196/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9176 - loss: 0.2245 - val_accuracy: 0.9859 - val_loss: 0.0544
# Epoch 197/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9018 - loss: 0.2722 - val_accuracy: 0.9829 - val_loss: 0.0475
# Epoch 198/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9165 - loss: 0.2139 - val_accuracy: 0.9729 - val_loss: 0.0686
# Epoch 199/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9029 - loss: 0.2667 - val_accuracy: 0.9900 - val_loss: 0.0405
# Epoch 200/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9271 - loss: 0.1830 - val_accuracy: 0.9841 - val_loss: 0.0466
# Epoch 201/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9165 - loss: 0.2226 - val_accuracy: 0.9876 - val_loss: 0.0361
# Epoch 202/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9053 - loss: 0.2386 - val_accuracy: 0.9894 - val_loss: 0.0321
# Epoch 203/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9035 - loss: 0.2629 - val_accuracy: 0.9694 - val_loss: 0.1004
# Epoch 204/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9071 - loss: 0.2456 - val_accuracy: 0.9882 - val_loss: 0.0378
# Epoch 205/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9312 - loss: 0.1892 - val_accuracy: 0.9935 - val_loss: 0.0288
# Epoch 206/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9159 - loss: 0.2333 - val_accuracy: 0.9753 - val_loss: 0.0774
# Epoch 207/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9235 - loss: 0.1961 - val_accuracy: 0.9912 - val_loss: 0.0360
# Epoch 208/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9065 - loss: 0.2293 - val_accuracy: 0.9918 - val_loss: 0.0378
# Epoch 209/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9206 - loss: 0.1900 - val_accuracy: 0.9918 - val_loss: 0.0366
# Epoch 210/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9188 - loss: 0.1948 - val_accuracy: 0.9906 - val_loss: 0.0365
# Epoch 211/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9135 - loss: 0.2102 - val_accuracy: 0.9865 - val_loss: 0.0429
# Epoch 212/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9253 - loss: 0.2022 - val_accuracy: 0.9776 - val_loss: 0.0634
# Epoch 213/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9165 - loss: 0.2045 - val_accuracy: 0.9941 - val_loss: 0.0377
# Epoch 214/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9206 - loss: 0.1898 - val_accuracy: 0.9882 - val_loss: 0.0459
# Epoch 215/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9141 - loss: 0.2532 - val_accuracy: 0.9876 - val_loss: 0.0503
# Epoch 216/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9094 - loss: 0.2324 - val_accuracy: 0.9782 - val_loss: 0.0588
# Epoch 217/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9218 - loss: 0.2019 - val_accuracy: 0.9829 - val_loss: 0.0478
# Epoch 218/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9100 - loss: 0.2315 - val_accuracy: 0.9894 - val_loss: 0.0325
# Epoch 219/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9335 - loss: 0.1788 - val_accuracy: 0.9924 - val_loss: 0.0329
# Epoch 220/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9324 - loss: 0.1789 - val_accuracy: 0.9900 - val_loss: 0.0337
# Epoch 221/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9329 - loss: 0.1878 - val_accuracy: 0.9853 - val_loss: 0.0436
# Epoch 222/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9200 - loss: 0.2067 - val_accuracy: 0.9906 - val_loss: 0.0371
# Epoch 223/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9241 - loss: 0.2117 - val_accuracy: 0.9871 - val_loss: 0.0468
# Epoch 224/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9194 - loss: 0.2110 - val_accuracy: 0.9806 - val_loss: 0.0566
# Epoch 225/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9188 - loss: 0.2016 - val_accuracy: 0.9882 - val_loss: 0.0457
# Epoch 226/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9182 - loss: 0.2015 - val_accuracy: 0.9906 - val_loss: 0.0290
# Epoch 227/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9329 - loss: 0.1884 - val_accuracy: 0.9871 - val_loss: 0.0470
# Epoch 228/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9247 - loss: 0.2037 - val_accuracy: 0.9865 - val_loss: 0.0411
# Epoch 229/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9206 - loss: 0.1939 - val_accuracy: 0.9959 - val_loss: 0.0263
# Epoch 230/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9247 - loss: 0.2017 - val_accuracy: 0.9876 - val_loss: 0.0411
# Epoch 231/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9176 - loss: 0.2011 - val_accuracy: 0.9812 - val_loss: 0.0511
# Epoch 232/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9112 - loss: 0.2386 - val_accuracy: 0.9871 - val_loss: 0.0587
# Epoch 233/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9059 - loss: 0.2464 - val_accuracy: 0.9824 - val_loss: 0.0473
# Epoch 234/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9182 - loss: 0.2035 - val_accuracy: 0.9971 - val_loss: 0.0247
# Epoch 235/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9224 - loss: 0.2095 - val_accuracy: 0.9876 - val_loss: 0.0502
# Epoch 236/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9335 - loss: 0.1878 - val_accuracy: 0.9941 - val_loss: 0.0248
# Epoch 237/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9312 - loss: 0.1735 - val_accuracy: 0.9906 - val_loss: 0.0320
# Epoch 238/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9235 - loss: 0.1904 - val_accuracy: 0.9871 - val_loss: 0.0376
# Epoch 239/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9112 - loss: 0.2306 - val_accuracy: 0.9865 - val_loss: 0.0464
# Epoch 240/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9271 - loss: 0.2251 - val_accuracy: 0.9882 - val_loss: 0.0323
# Epoch 241/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9200 - loss: 0.2056 - val_accuracy: 0.9771 - val_loss: 0.0675
# Epoch 242/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9065 - loss: 0.2565 - val_accuracy: 0.9635 - val_loss: 0.1090
# Epoch 243/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9153 - loss: 0.2300 - val_accuracy: 0.9888 - val_loss: 0.0399
# Epoch 244/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9265 - loss: 0.1897 - val_accuracy: 0.9924 - val_loss: 0.0358
# Epoch 245/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9353 - loss: 0.1856 - val_accuracy: 0.9918 - val_loss: 0.0273
# Epoch 246/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9276 - loss: 0.1947 - val_accuracy: 0.9918 - val_loss: 0.0316
# Epoch 247/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9247 - loss: 0.1857 - val_accuracy: 0.9824 - val_loss: 0.0513
# Epoch 248/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9282 - loss: 0.1888 - val_accuracy: 0.9859 - val_loss: 0.0462
# Epoch 249/250
# 213/213 - 1s - 5ms/step - accuracy: 0.9194 - loss: 0.2166 - val_accuracy: 0.9941 - val_loss: 0.0335
# Epoch 250/250
# 213/213 - 1s - 6ms/step - accuracy: 0.9282 - loss: 0.1785 - val_accuracy: 0.9912 - val_loss: 0.0364
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Classification Report (4 Qubits):
#               precision    recall  f1-score   support
#
#        Happy       1.00      1.00      1.00       297
#          Sad       1.00      0.99      0.99        68
#        Angry       1.00      1.00      1.00        98
#    Surprised       0.99      0.99      0.99       144
#      Neutral       0.99      0.99      0.99       407
#    Disgusted       0.99      0.98      0.98       136
#         Fear       0.99      0.99      0.99       298
#       Sleepy       1.00      0.97      0.98        33
#     Contempt       0.98      1.00      0.99       219
#
#     accuracy                           0.99      1700
#    macro avg       0.99      0.99      0.99      1700
# weighted avg       0.99      0.99      0.99      1700
# Test Accuracy (4 Qubits): 0.9912
# === Final Accuracy Comparison ===
# 4 Qubits: Accuracy = 0.9912

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt

# Function to create and display detailed quantum circuits
def show_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    # Random parameters for encoding & random layers
    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)  # Sample classical input for encoding

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding using RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Apply random entangling layers
        RandomLayers(rand_params, wires=range(n_qubits))

        # Measurement
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw circuit
    fig, ax = qml.draw_mpl(circuit)(sample_inputs)
    plt.title(f"Quantum Circuit with {n_qubits} Qubits & {n_layers} Random Layers")
    plt.show()

# Show circuits for 4, 6, 8, 10, 12 qubits
for q in [4, 6, 8, 10, 12]:
    show_detailed_circuit(n_qubits=q, n_layers=2)
