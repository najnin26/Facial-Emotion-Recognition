# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.42.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.42 (from pennylane)
#   Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (25.0)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.42->pennylane)
#   Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pennylane) (2.4.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.6.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pennylane) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pennylane) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pennylane) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pennylane) (2024.2.0)
# Downloading pennylane-0.42.1-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 74.7 MB/s eta 0:00:00:00:01
# Downloading autoray-0.7.2-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 39.1 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.42.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 70.9 MB/s eta 0:00:00:00:01
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 64.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 8.6 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.30.0.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 100.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: appdirs, scipy-openblas32, autoray, diastatic-malt, rustworkx, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.2 diastatic-malt-2.15.2 pennylane-0.42.1 pennylane-lightning-0.42.0 rustworkx-0.16.0 scipy-openblas32-0.3.30.0.2

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report
import itertools
     

# Constants
IMG_SIZE = 48
DATA_DIR = '/kaggle/input/happy-and-sad-image'
     

import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline
train1 = os.listdir(DATA_DIR)
train2 = os.listdir(DATA_DIR)
print(f'Train1 - {train1}')
print(f'Train2 - {train2}')
data_dir = DATA_DIR
print(os.listdir(data_dir))
classes_train = os.listdir(data_dir + f"/{train1[3]}")
classes_valid = os.listdir(data_dir + f"/{train2[3]}")
print(f'Train Classes - {classes_train}')
print(f'Validation Classes - {classes_valid}')
     
import torchvision.transforms as transforms

# Define transforms
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor()
])
     

import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Load the datasets
train_dataset = ImageFolder(root=os.path.join(DATA_DIR, train1[3]), transform=transform)
val_dataset = ImageFolder(root=os.path.join(DATA_DIR, train2[3]), transform=transform)
     
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Load the datasets
train_dataset = ImageFolder(root=os.path.join(DATA_DIR, train1[3]), transform=transform)
val_dataset = ImageFolder(root=os.path.join(DATA_DIR, train2[3]), transform=transform)
     

def plot_class_distribution(dataset, title):
    class_counts = {}
    for _, label in dataset:
        class_name = emotion_labels[label]
        class_counts[class_name] = class_counts.get(class_name, 0) + 1

    plt.figure(figsize=(10, 6))
    plt.bar(class_counts.keys(), class_counts.values(), color='skyblue', alpha=0.7)
    plt.title(f'{title} - Class Distribution')
    plt.xlabel('Emotions')
    plt.ylabel('Number of Samples')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    return class_counts

# Define emotion_labels based on the dataset classes
emotion_labels = {i: class_name for i, class_name in enumerate(train_dataset.classes)}

train_counts = plot_class_distribution(train_dataset, 'Training Dataset')
val_counts = plot_class_distribution(val_dataset, 'Validation Dataset')

# ------------------------- Convert Dataset to NumPy Arrays -------------------------

def dataset_to_numpy(dataset, n_samples):
    images = []
    labels = []
    # Use the actual number of samples available in the dataset
    num_samples_to_extract = min(n_samples, len(dataset))
    for i in range(num_samples_to_extract):
        img_tensor, label = dataset[i]
        img_array = img_tensor.numpy().transpose(1, 2, 0)  # (1, 48, 48) → (48, 48, 1)
        images.append(img_array)
        labels.append(label)
    return np.array(images), np.array(labels)

# Define number of samples to extract (these values will be capped by the actual dataset size)
n_train = 5000
n_test = 3000

train_images, train_labels = dataset_to_numpy(train_dataset, n_train)
test_images, test_labels = dataset_to_numpy(val_dataset, n_test)

# Clip values (just in case)
train_images = np.clip(train_images, 0.0, 1.0)
test_images = np.clip(test_images, 0.0, 1.0)

# One-hot encode labels
train_labels_categorical = to_categorical(train_labels, num_classes=len(emotion_labels))
test_labels_categorical = to_categorical(test_labels, num_classes=len(emotion_labels))

# ------------------------- Final Shape Checks -------------------------

print(f"Train images shape: {train_images.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Train labels shape: {train_labels_categorical.shape}")
print(f"Test labels shape: {test_labels_categorical.shape}")
# Out:
# Train1 - ['sad.jpg', 'saadgirl.jpg', 'happy.jpg', 'data', 'very-happy-people.jpg']
# Train2 - ['sad.jpg', 'saadgirl.jpg', 'happy.jpg', 'data', 'very-happy-people.jpg']
# ['sad.jpg', 'saadgirl.jpg', 'happy.jpg', 'data', 'very-happy-people.jpg']
# Train Classes - ['sad', 'happy']
# Validation Classes - ['sad', 'happy']
# Train images shape: (171, 48, 48, 1)
# Test images shape: (171, 48, 48, 1)
# Train labels shape: (171, 2)
# Test labels shape: (171, 2)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Fix seeds
np.random.seed(0)
tf.random.set_seed(0)

# Define qubit patch sizes
qubit_patch_shapes = {
    4: (2, 2),
    6: (3, 2),
    8: (4, 2),
    10: (5, 2),
    12: (4, 3),
}

# Function to create quantum circuit
def create_circuit(n_qubits, n_layers=1):
    dev = qml.device("default.qubit", wires=n_qubits)
    rand_params = np.random.uniform(high=2*np.pi, size=(n_layers, n_qubits))

    @qml.qnode(dev)
    def circuit(phi):
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)
        RandomLayers(rand_params, wires=range(n_qubits))
        return [qml.expval(qml.PauliZ(j)) for j in range(n_qubits)]

    return circuit

# Quantum convolution function
def quanv(image, circuit, patch_h, patch_w):
    out_h = (image.shape[0] - patch_h) // 2 + 1
    out_w = (image.shape[1] - patch_w) // 2 + 1
    n_qubits = patch_h * patch_w
    out = np.zeros((out_h, out_w, n_qubits))
    for j in range(0, image.shape[0] - patch_h + 1, 2):
        for k in range(0, image.shape[1] - patch_w + 1, 2):
            patch = image[j:j+patch_h, k:k+patch_w, 0].flatten()
            q_results = circuit(patch)
            out[j//2, k//2, :] = q_results
    return out

# Classical model
def build_model(input_shape):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(64, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Run experiment for different qubits
results = {}
for n_qubits in [4, 6, 8, 10, 12]:
    print(f"\n=== Running for {n_qubits} Qubits ===")
    patch_h, patch_w = qubit_patch_shapes[n_qubits]
    circuit = create_circuit(n_qubits)

    # Show quantum circuit diagram
    print(f"\nQuantum Circuit for {n_qubits} Qubits:")
    fig, ax = qml.draw_mpl(circuit)(np.random.rand(n_qubits))
    plt.show()

    # Quantum preprocess images
    print("Quantum pre-processing (train)...")
    q_train_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in train_images])
    print("Quantum pre-processing (test)...")
    q_test_images = np.array([quanv(img, circuit, patch_h, patch_w) for img in test_images])

    # Build & train model
    model = build_model(q_train_images.shape[1:])
    model.fit(q_train_images, train_labels, validation_data=(q_test_images, test_labels),
              epochs=30, batch_size=8, verbose=2)

    # Predictions
    y_pred = np.argmax(model.predict(q_test_images), axis=1)

    # Classification report
    print(f"\nClassification Report ({n_qubits} Qubits):")
    print(classification_report(test_labels, y_pred, target_names=emotion_labels.values()))

    # Confusion matrix
    cm = confusion_matrix(test_labels, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=emotion_labels.values(),
                yticklabels=emotion_labels.values())
    plt.title(f"Confusion Matrix - {n_qubits} Qubits")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    # Evaluate accuracy
    acc = model.evaluate(q_test_images, test_labels, verbose=0)[1]
    print(f"Test Accuracy: {acc:.4f}")
    results[n_qubits] = acc

# Compare accuracies
plt.figure(figsize=(8, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Quantum CNN Accuracy vs Number of Qubits")
plt.xlabel("Number of Qubits")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

print("\n=== Final Accuracy Comparison ===")
for q, a in results.items():
    print(f"{q} Qubits: {a:.4f}")
# Out:
# === Running for 4 Qubits ===
#
# Quantum Circuit for 4 Qubits:
# Quantum pre-processing (train)...
# Quantum pre-processing (test)...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-07-28 15:23:25.767788: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/30
# 22/22 - 2s - 106ms/step - accuracy: 0.6257 - loss: 0.8875 - val_accuracy: 0.7778 - val_loss: 0.4613
# Epoch 2/30
# 22/22 - 0s - 8ms/step - accuracy: 0.7368 - loss: 0.5116 - val_accuracy: 0.8538 - val_loss: 0.3809
# Epoch 3/30
# 22/22 - 0s - 8ms/step - accuracy: 0.7895 - loss: 0.5045 - val_accuracy: 0.8830 - val_loss: 0.3570
# Epoch 4/30
# 22/22 - 0s - 9ms/step - accuracy: 0.8596 - loss: 0.3904 - val_accuracy: 0.9006 - val_loss: 0.3037
# Epoch 5/30
# 22/22 - 0s - 8ms/step - accuracy: 0.8713 - loss: 0.3013 - val_accuracy: 0.9357 - val_loss: 0.2233
# Epoch 6/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9240 - loss: 0.2582 - val_accuracy: 0.9591 - val_loss: 0.1895
# Epoch 7/30
# 22/22 - 0s - 9ms/step - accuracy: 0.8947 - loss: 0.2323 - val_accuracy: 0.9708 - val_loss: 0.1623
# Epoch 8/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9181 - loss: 0.2058 - val_accuracy: 0.9708 - val_loss: 0.1407
# Epoch 9/30
# 22/22 - 0s - 8ms/step - accuracy: 0.8889 - loss: 0.2275 - val_accuracy: 0.9883 - val_loss: 0.1312
# Epoch 10/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9181 - loss: 0.1888 - val_accuracy: 0.9942 - val_loss: 0.1108
# Epoch 11/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9532 - loss: 0.1422 - val_accuracy: 0.9883 - val_loss: 0.0887
# Epoch 12/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.1111 - val_accuracy: 0.9942 - val_loss: 0.0704
# Epoch 13/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.1168 - val_accuracy: 0.9825 - val_loss: 0.1020
# Epoch 14/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.1138 - val_accuracy: 0.9942 - val_loss: 0.0504
# Epoch 15/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9766 - loss: 0.0991 - val_accuracy: 0.9883 - val_loss: 0.0601
# Epoch 16/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.0761 - val_accuracy: 1.0000 - val_loss: 0.0330
# Epoch 17/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9766 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 0.0431
# Epoch 18/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0755 - val_accuracy: 1.0000 - val_loss: 0.0306
# Epoch 19/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9825 - loss: 0.0809 - val_accuracy: 0.9883 - val_loss: 0.0490
# Epoch 20/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9825 - loss: 0.0633 - val_accuracy: 0.9825 - val_loss: 0.0501
# Epoch 21/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0552 - val_accuracy: 0.9649 - val_loss: 0.0900
# Epoch 22/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9766 - loss: 0.0793 - val_accuracy: 0.9649 - val_loss: 0.0650
# Epoch 23/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0551 - val_accuracy: 1.0000 - val_loss: 0.0208
# Epoch 24/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9883 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 25/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 26/30
# 22/22 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 27/30
# 22/22 - 0s - 8ms/step - accuracy: 0.9825 - loss: 0.0489 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 28/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0478 - val_accuracy: 1.0000 - val_loss: 0.0228
# Epoch 29/30
# 22/22 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 30/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0137
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Classification Report (4 Qubits):
#               precision    recall  f1-score   support
#
#        happy       1.00      1.00      1.00       102
#          sad       1.00      1.00      1.00        69
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171
# Test Accuracy: 1.0000
#
# === Running for 6 Qubits ===
#
# Quantum Circuit for 6 Qubits:
# Quantum pre-processing (train)...
# Quantum pre-processing (test)...
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 - 2s - 75ms/step - accuracy: 0.6257 - loss: 0.9094 - val_accuracy: 0.8538 - val_loss: 0.4291
# Epoch 2/30
# 22/22 - 0s - 9ms/step - accuracy: 0.7719 - loss: 0.5034 - val_accuracy: 0.8947 - val_loss: 0.3095
# Epoch 3/30
# 22/22 - 0s - 9ms/step - accuracy: 0.7719 - loss: 0.4999 - val_accuracy: 0.9240 - val_loss: 0.2807
# Epoch 4/30
# 22/22 - 0s - 10ms/step - accuracy: 0.8246 - loss: 0.4067 - val_accuracy: 0.9240 - val_loss: 0.2349
# Epoch 5/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9123 - loss: 0.2511 - val_accuracy: 0.9474 - val_loss: 0.1616
# Epoch 6/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9064 - loss: 0.2357 - val_accuracy: 0.9883 - val_loss: 0.1198
# Epoch 7/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9181 - loss: 0.1985 - val_accuracy: 0.9825 - val_loss: 0.0975
# Epoch 8/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9181 - loss: 0.2426 - val_accuracy: 0.9532 - val_loss: 0.1341
# Epoch 9/30
# 22/22 - 0s - 9ms/step - accuracy: 0.8772 - loss: 0.2946 - val_accuracy: 0.9825 - val_loss: 0.1127
# Epoch 10/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9064 - loss: 0.2247 - val_accuracy: 1.0000 - val_loss: 0.0749
# Epoch 11/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9649 - loss: 0.1133 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 12/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9532 - loss: 0.1059 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 13/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0626 - val_accuracy: 1.0000 - val_loss: 0.0304
# Epoch 14/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9766 - loss: 0.0763 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 15/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0574 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 16/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0383 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 17/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0430 - val_accuracy: 1.0000 - val_loss: 0.0209
# Epoch 18/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0594 - val_accuracy: 0.9942 - val_loss: 0.0335
# Epoch 19/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0578 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 20/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 21/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0384 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 22/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0423 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 23/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0221 - val_accuracy: 0.9942 - val_loss: 0.0164
# Epoch 24/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 25/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 26/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 27/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 28/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 29/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0320 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 30/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 0.0087
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Classification Report (6 Qubits):
#               precision    recall  f1-score   support
#
#        happy       1.00      1.00      1.00       102
#          sad       1.00      1.00      1.00        69
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171
# Test Accuracy: 1.0000
#
# === Running for 8 Qubits ===
#
# Quantum Circuit for 8 Qubits:
# Quantum pre-processing (train)...
# Quantum pre-processing (test)...
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 - 2s - 76ms/step - accuracy: 0.5848 - loss: 1.1408 - val_accuracy: 0.8070 - val_loss: 0.4238
# Epoch 2/30
# 22/22 - 0s - 9ms/step - accuracy: 0.7602 - loss: 0.5262 - val_accuracy: 0.9006 - val_loss: 0.3205
# Epoch 3/30
# 22/22 - 0s - 9ms/step - accuracy: 0.8246 - loss: 0.4079 - val_accuracy: 0.9006 - val_loss: 0.2390
# Epoch 4/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9181 - loss: 0.2722 - val_accuracy: 0.9298 - val_loss: 0.1996
# Epoch 5/30
# 22/22 - 0s - 9ms/step - accuracy: 0.8772 - loss: 0.2943 - val_accuracy: 0.9591 - val_loss: 0.1612
# Epoch 6/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9123 - loss: 0.2420 - val_accuracy: 0.9708 - val_loss: 0.1371
# Epoch 7/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9240 - loss: 0.1978 - val_accuracy: 0.9766 - val_loss: 0.0989
# Epoch 8/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9532 - loss: 0.1317 - val_accuracy: 0.9942 - val_loss: 0.0732
# Epoch 9/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9357 - loss: 0.1336 - val_accuracy: 0.9825 - val_loss: 0.0651
# Epoch 10/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9591 - loss: 0.1147 - val_accuracy: 1.0000 - val_loss: 0.0418
# Epoch 11/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9766 - loss: 0.0936 - val_accuracy: 0.9942 - val_loss: 0.0343
# Epoch 12/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0703 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 13/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0394 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 14/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0439 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 15/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 16/30
# 22/22 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 17/30
# 22/22 - 0s - 11ms/step - accuracy: 0.9942 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 18/30
# 22/22 - 0s - 11ms/step - accuracy: 0.9883 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 19/30
# 22/22 - 0s - 11ms/step - accuracy: 0.9825 - loss: 0.0577 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 20/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9708 - loss: 0.0726 - val_accuracy: 0.9883 - val_loss: 0.0351
# Epoch 21/30
# 22/22 - 0s - 11ms/step - accuracy: 0.9708 - loss: 0.0694 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 22/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9942 - loss: 0.0365 - val_accuracy: 0.9883 - val_loss: 0.0247
# Epoch 23/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9942 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 24/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 25/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 26/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 27/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 28/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 29/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 30/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 0.0026
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Classification Report (8 Qubits):
#               precision    recall  f1-score   support
#
#        happy       1.00      1.00      1.00       102
#          sad       1.00      1.00      1.00        69
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171
# Test Accuracy: 1.0000
#
# === Running for 10 Qubits ===
#
# Quantum Circuit for 10 Qubits:
# Quantum pre-processing (train)...
# Quantum pre-processing (test)...
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 - 2s - 75ms/step - accuracy: 0.5906 - loss: 1.2914 - val_accuracy: 0.8129 - val_loss: 0.4293
# Epoch 2/30
# 22/22 - 0s - 9ms/step - accuracy: 0.7836 - loss: 0.5793 - val_accuracy: 0.9240 - val_loss: 0.2560
# Epoch 3/30
# 22/22 - 0s - 10ms/step - accuracy: 0.8655 - loss: 0.3832 - val_accuracy: 0.9474 - val_loss: 0.2263
# Epoch 4/30
# 22/22 - 0s - 10ms/step - accuracy: 0.8363 - loss: 0.4375 - val_accuracy: 0.9532 - val_loss: 0.1659
# Epoch 5/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9240 - loss: 0.2296 - val_accuracy: 0.9708 - val_loss: 0.1486
# Epoch 6/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9123 - loss: 0.1941 - val_accuracy: 0.9766 - val_loss: 0.1093
# Epoch 7/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9474 - loss: 0.1309 - val_accuracy: 0.9825 - val_loss: 0.0828
# Epoch 8/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9474 - loss: 0.1289 - val_accuracy: 0.9825 - val_loss: 0.0588
# Epoch 9/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9708 - loss: 0.1395 - val_accuracy: 0.9942 - val_loss: 0.0539
# Epoch 10/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9766 - loss: 0.0907 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 11/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9649 - loss: 0.0930 - val_accuracy: 1.0000 - val_loss: 0.0349
# Epoch 12/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9649 - loss: 0.0819 - val_accuracy: 1.0000 - val_loss: 0.0349
# Epoch 13/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9883 - loss: 0.0544 - val_accuracy: 1.0000 - val_loss: 0.0321
# Epoch 14/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9883 - loss: 0.0574 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 15/30
# 22/22 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0375 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 16/30
# 22/22 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0295 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 17/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0333 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 18/30
# 22/22 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 19/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.0541 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 20/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0438 - val_accuracy: 0.9942 - val_loss: 0.0187
# Epoch 21/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9708 - loss: 0.0978 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 22/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9649 - loss: 0.1163 - val_accuracy: 1.0000 - val_loss: 0.0186
# Epoch 23/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9591 - loss: 0.0906 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 24/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9649 - loss: 0.1174 - val_accuracy: 1.0000 - val_loss: 0.0216
# Epoch 25/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9649 - loss: 0.0867 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 26/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9708 - loss: 0.0613 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 27/30
# 22/22 - 0s - 11ms/step - accuracy: 0.9883 - loss: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 28/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 29/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 30/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9883 - loss: 0.0291 - val_accuracy: 1.0000 - val_loss: 0.0052
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Classification Report (10 Qubits):
#               precision    recall  f1-score   support
#
#        happy       1.00      1.00      1.00       102
#          sad       1.00      1.00      1.00        69
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171
# Test Accuracy: 1.0000
#
# === Running for 12 Qubits ===
#
# Quantum Circuit for 12 Qubits:
# Quantum pre-processing (train)...
# Quantum pre-processing (test)...
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 - 2s - 79ms/step - accuracy: 0.5965 - loss: 1.0467 - val_accuracy: 0.7953 - val_loss: 0.7970
# Epoch 2/30
# 22/22 - 0s - 9ms/step - accuracy: 0.7251 - loss: 0.8511 - val_accuracy: 0.8538 - val_loss: 0.3432
# Epoch 3/30
# 22/22 - 0s - 9ms/step - accuracy: 0.7602 - loss: 0.6520 - val_accuracy: 0.8772 - val_loss: 0.2913
# Epoch 4/30
# 22/22 - 0s - 9ms/step - accuracy: 0.8070 - loss: 0.4600 - val_accuracy: 0.9708 - val_loss: 0.1787
# Epoch 5/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9006 - loss: 0.2820 - val_accuracy: 0.9357 - val_loss: 0.1625
# Epoch 6/30
# 22/22 - 0s - 10ms/step - accuracy: 0.8655 - loss: 0.2545 - val_accuracy: 0.9474 - val_loss: 0.1401
# Epoch 7/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9357 - loss: 0.1938 - val_accuracy: 0.9766 - val_loss: 0.0989
# Epoch 8/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9415 - loss: 0.1525 - val_accuracy: 0.9825 - val_loss: 0.0771
# Epoch 9/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9532 - loss: 0.1442 - val_accuracy: 0.9942 - val_loss: 0.0631
# Epoch 10/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9532 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0552
# Epoch 11/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9708 - loss: 0.0933 - val_accuracy: 1.0000 - val_loss: 0.0354
# Epoch 12/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9942 - loss: 0.0443 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 13/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9708 - loss: 0.0667 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 14/30
# 22/22 - 0s - 9ms/step - accuracy: 0.9825 - loss: 0.0708 - val_accuracy: 1.0000 - val_loss: 0.0266
# Epoch 15/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9825 - loss: 0.0635 - val_accuracy: 0.9942 - val_loss: 0.0452
# Epoch 16/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9825 - loss: 0.0465 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 17/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 18/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9591 - loss: 0.0702 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 19/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9883 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 20/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9766 - loss: 0.0504 - val_accuracy: 1.0000 - val_loss: 0.0154
# Epoch 21/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9883 - loss: 0.0349 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 22/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9942 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 23/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9942 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 24/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9942 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 25/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9942 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 26/30
# 22/22 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 27/30
# 22/22 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 28/30
# 22/22 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 29/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9766 - loss: 0.0474 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 30/30
# 22/22 - 0s - 10ms/step - accuracy: 0.9883 - loss: 0.0456 - val_accuracy: 1.0000 - val_loss: 0.0190
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Classification Report (12 Qubits):
#               precision    recall  f1-score   support
#
#        happy       1.00      1.00      1.00       102
#          sad       1.00      1.00      1.00        69
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171
# Test Accuracy: 1.0000
# === Final Accuracy Comparison ===
# 4 Qubits: 1.0000
# 6 Qubits: 1.0000
# 8 Qubits: 1.0000
# 10 Qubits: 1.0000
# 12 Qubits: 1.0000

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import matplotlib.pyplot as plt

# Function to create and display detailed quantum circuits
def show_detailed_circuit(n_qubits=4, n_layers=2):
    dev = qml.device("default.qubit", wires=n_qubits)

    # Random parameters for encoding & random layers
    rand_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits))
    sample_inputs = np.random.rand(n_qubits)  # Sample classical input for encoding

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding using RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Apply random entangling layers
        RandomLayers(rand_params, wires=range(n_qubits))

        # Measurement
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw circuit
    fig, ax = qml.draw_mpl(circuit)(sample_inputs)
    plt.title(f"Quantum Circuit with {n_qubits} Qubits & {n_layers} Random Layers")
    plt.show()

# Show circuits for 4, 6, 8, 10, 12 qubits
for q in [4, 6, 8, 10, 12]:
    show_detailed_circuit(n_qubits=q, n_layers=2)

# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt

def save_explicit_randomlayer_circuit(n_qubits=4, n_layers=2, save_dir="./circuits"):
    import os
    os.makedirs(save_dir, exist_ok=True)  # Ensure save directory exists

    dev = qml.device("default.qubit", wires=n_qubits)

    # Random rotation parameters (RX, RY, RZ per qubit per layer)
    rotation_params = np.random.uniform(0, 2*np.pi, size=(n_layers, n_qubits, 3))

    # Entangling pairs (nearest-neighbor entanglement)
    entangling_pairs = [
        [(i, (i+1) % n_qubits) for i in range(n_qubits - 1)]
        for _ in range(n_layers)
    ]

    sample_inputs = np.random.rand(n_qubits)  # Random classical inputs

    @qml.qnode(dev)
    def circuit(phi):
        # Encoding layer: RY rotations
        for j in range(n_qubits):
            qml.RY(np.pi * phi[j], wires=j)

        # Explicit random layers: rotations + CNOT entanglements
        for layer in range(n_layers):
            # Single-qubit random rotations
            for q in range(n_qubits):
                qml.RX(rotation_params[layer, q, 0], wires=q)
                qml.RY(rotation_params[layer, q, 1], wires=q)
                qml.RZ(rotation_params[layer, q, 2], wires=q)

            # CNOT entangling gates
            for (control, target) in entangling_pairs[layer]:
                qml.CNOT(wires=[control, target])

        # Measurements
        return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

    # Draw and save the circuit
    fig, ax = qml.draw_mpl(circuit)(sample_inputs)
    plt.title(f"Quantum Circuit ({n_qubits} Qubits, {n_layers} Layers)", fontsize=14)
    save_path = f"{save_dir}/circuit_{n_qubits}_qubits.pdf"
    fig.savefig(save_path, format="pdf", bbox_inches="tight")
    plt.close(fig)
    print(f"✅ Saved: {save_path}")

# Generate and save circuits for all qubit configurations
for q in [4, 6, 8, 10, 12]:
    save_explicit_randomlayer_circuit(n_qubits=q, n_layers=2)
# Out:
# ✅ Saved: ./circuits/circuit_4_qubits.pdf
# ✅ Saved: ./circuits/circuit_6_qubits.pdf
# ✅ Saved: ./circuits/circuit_8_qubits.pdf
# ✅ Saved: ./circuits/circuit_10_qubits.pdf
# ✅ Saved: ./circuits/circuit_12_qubits.pdf
